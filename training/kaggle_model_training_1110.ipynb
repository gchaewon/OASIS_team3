# %% [markdown]
# kaggle 데이터를 사용하여 만든 이진 분류 모델
#
# 데이터를 non / very mild + mild + moderate 두가지 그룹으로 묶어서 진행
#
# - non (1464) -> 0
# - very mild (488) + mild (488) + moderate (488) -> 1 로 인코딩

# %% [markdown]
# ## 0. Import Library

# %%
# !pip install tqdm
# !pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /Users/chaewon/Library/Python/3.9/lib/python/site-packages (4.66.6)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imblearn in /Users/chaewon/Library/Python/3.9/lib/python/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /Users/chaewon/Library/Python/3.9/lib/python/site-packages (from imblearn) (0.12.4)
# Requirement already satisfied: numpy>=1.17.3 in /Users/chaewon/Library/Python/3.9/lib/python/site-packages (from imbalanced-learn->imblearn) (1.26.0)
# Requirement already satisfied: scipy>=1.5.0 in /Users/chaewon/Library/Python/3.9/lib/python/site-packages (from imbalanced-learn->imblearn) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/chaewon/Library/Python/3.9/lib/python/site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: joblib>=1.1.1 in /Users/chaewon/Library/Python/3.9/lib/python/site-packages (from imbalanced-learn->imblearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/chaewon/Library/Python/3.9/lib/python/site-packages (from imbalanced-learn->imblearn) (3.2.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import os 
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf

import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from tqdm import tqdm

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input  
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import AUC, Recall

from keras.models import Sequential, load_model
from keras.layers import Conv2D,Flatten,Dense,Dropout,BatchNormalization,MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import numpy as np
import pandas as pd
import tensorflow as tf

# %% [markdown]
# ## 1. Load Data

# %%
# 경로 설정
data_dir = "../kaggle/"

# 이미지 리스트 
non_demented = []
very_mild_demented = []
mild_demented = []
moderate_demented = []

# 카테고리 리스트 및 경로 초기화
path_list = ["Mild Dementia", "Moderate Dementia", 
             "Non Demented", "Very mild Dementia"]

# %%
# 카테고리 별 이미지 경로 저장을 위한 딕셔너리 초기화
image_paths = {
    "Mild Dementia": [],
    "Moderate Dementia": [],
    "Non Demented": [],
    "Very mild Dementia": []
}

# 각 카테고리 별 경로 추가
for category in path_list:
    category_dir = os.path.join(data_dir, category)
    for dirname, _, filenames in os.walk(category_dir):
        for filename in filenames:
            image_paths[category].append(os.path.join(dirname, filename))

# 확인
for category in path_list:
    print(f'{category}: {len(image_paths[category])} images')
# Out:
# Mild Dementia: 5002 images
# Moderate Dementia: 488 images
# Non Demented: 67222 images
# Very mild Dementia: 13725 images

# %%
# 각 카테고리별 파일 경로 리스트
non_demented = []
very_mild_demented = []
mild_demented = []
moderate_demented = []

images, labels = [], []

# %%
# 각 카테고리 폴더 내 파일 경로를 리스트에 추가
for category in tqdm(path_list):
    category_dir = os.path.join(data_dir, category)
    for root, _, filenames in os.walk(category_dir):
        for filename in filenames:
            image_path = os.path.join(root, filename)
            images.append(image_path)
            labels.append(category)
            if category == "Non Demented":
                non_demented.append(image_path)
            elif category == "Very mild Dementia":
                very_mild_demented.append(image_path)
            elif category == "Mild Dementia":
                mild_demented.append(image_path)
            elif category == "Moderate Dementia":
                moderate_demented.append(image_path)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 29.38it/s]

# %%
# 이미지 경로와 레이블을 포함하는 DataFrame 생성
df = pd.DataFrame({'image': images, 'label': labels})
df.head()
# Out:
#                                                image          label
# 0  ../kaggle/Mild Dementia/OAS1_0137_MR1_mpr-3_13...  Mild Dementia
# 1  ../kaggle/Mild Dementia/OAS1_0291_MR1_mpr-3_10...  Mild Dementia
# 2  ../kaggle/Mild Dementia/OAS1_0278_MR1_mpr-2_11...  Mild Dementia
# 3  ../kaggle/Mild Dementia/OAS1_0382_MR1_mpr-4_12...  Mild Dementia
# 4  ../kaggle/Mild Dementia/OAS1_0316_MR1_mpr-1_14...  Mild Dementia

# %%
# 이미지 경로 저장
df.to_csv('../gradcam/kaggle_image_labels.csv', index=False)

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x=df.label,palette='Set1')
ax.set_xlabel("Class",fontsize=20)
ax.set_ylabel("Count",fontsize=20)
plt.title('The Number Of Samples For Each Class',fontsize=20)
plt.grid(False)
plt.xticks(rotation=35)
plt.show()
# Out:
# /var/folders/s1/nf_zq41n2nd447kv5d44gx2h0000gn/T/ipykernel_96996/1748014159.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=df.label,palette='Set1')

# %%
plt.figure(figsize=(10,12))
for n,i in enumerate(np.random.randint(0,len(df),20)):
    plt.subplot(5,5,n+1)
    img=cv2.imread(df.image[i])
    img=cv2.resize(img,(224,224))
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')
    plt.title(df.label[i],fontsize=12)

# %% [markdown]
# ## 2. Preprocessing

# %%
data = []
result = []

# %% [markdown]
# ### 1) Label Encoding

# %%
encoder= OneHotEncoder()
encoder.fit([[0],[1],[2],[3]])
# Out:
# OneHotEncoder()

# %%
# 각 리스트에서 이미지를 읽어와 데이터와 결과에 추가하는 함수
def load_images(category_list, label):
    for image_path in category_list:
        img = Image.open(image_path).convert('RGB')
        img = img.resize((128, 128))
        img = np.array(img)
        data.append(img)
        result.append(encoder.transform([[label]]).toarray())

# %%
# 각 카테고리별로 이미지 로드
load_images(non_demented, 0)
load_images(very_mild_demented, 1)
load_images(mild_demented, 2)
load_images(moderate_demented, 3)

# %%
# 결과 데이터 변환 확인
data = np.array(data)
result = np.array(result).reshape(len(result), -1)
print(f"Data shape: {data.shape}, Result shape: {result.shape}")
# Out:
# Data shape: (86437, 128, 128, 3), Result shape: (86437, 4)

# %% [markdown]
# ### 2) Reshape data

# %%
X=np.array(data)
y=np.array(result)

y=y.reshape(X.shape[0],4)
y=np.argmax(y, axis=1)

# %% [markdown]
# ### 3) Balance data

# %%
# 그룹별 인덱스 추출
non_indices = np.where(y == 0)[0]          # non_demented
very_mild_indices = np.where(y == 1)[0]    # very_mild_demented
mild_indices = np.where(y == 2)[0]         # mild_demented
moderate_indices = np.where(y == 3)[0]     # moderate_demented

# 각 그룹에서 샘플 추출
np.random.seed(42)  

# non_demented에서 1464개 추출 (0으로 인코딩)
non_sample_indices = np.random.choice(non_indices, 1464, replace=False)

# very_mild_demented, mild_demented, moderate_demented에서 각각 488개씩 추출 (1로 인코딩)
very_mild_sample_indices = np.random.choice(very_mild_indices, 488, replace=False)
mild_sample_indices = np.random.choice(mild_indices, 488, replace=False)
moderate_sample_indices = np.random.choice(moderate_indices, 488, replace=False)

# 인덱스 결합
group_0_indices = non_sample_indices  
group_1_indices = np.concatenate([very_mild_sample_indices, mild_sample_indices, moderate_sample_indices])  

X_balanced = np.concatenate([X[group_0_indices], X[group_1_indices]])
y_balanced = np.concatenate([np.zeros(len(group_0_indices)), np.ones(len(group_1_indices))])

print("Balanced X shape:", X_balanced.shape)
print("Balanced y distribution:", np.bincount(y_balanced.astype(int)))
# Out:
# Balanced X shape: (2928, 128, 128, 3)
# Balanced y distribution: [1464 1464]

# %% [markdown]
# ### 3) Split data

# %%
X_train, X_test, y_train, y_test= train_test_split(X_balanced, y_balanced,test_size=0.2,random_state=42, shuffle = True)
print("X train shape: ", X_train.shape)
print("Ytrain shape: ", y_train.shape)
# Out:
# X train shape:  (2342, 128, 128, 3)
# Ytrain shape:  (2342,)

# %% [markdown]
# ## 3. Modeling

# %%
# CNN 모델 생성
def create_compile_model():
    model=Sequential()
    model.add(Conv2D(filters=32,kernel_size=2,padding='Same',input_shape = (128,128,3)))

    model.add(Conv2D(filters=32,kernel_size=2,padding='Same',activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(filters=64,kernel_size=2,padding='Same',activation='relu'))
    model.add(Conv2D(filters=64,kernel_size=2,padding='Same',activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(filters=128,kernel_size=2,padding='Same',activation='relu'))
    model.add(Conv2D(filters=128,kernel_size=2,padding='Same',activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256,activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(1,activation='sigmoid'))

    print(model.summary())

    model.compile(optimizer = 'adam',
                  loss = 'binary_crossentropy',
                   metrics=['accuracy',         
                           'Precision',       
                           'Recall',           
                           AUC()])             
    
    
    return model

# %%
early_stopping=EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=10,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=0,
)

checkpoint = ModelCheckpoint(
    filepath='../model/binary_model1110.keras',  
    monitor='val_loss',       
    save_best_only=True,       
    mode='min',               
    verbose=1               
)

# %% [markdown]
# ## 4. Training

# %%
model = create_compile_model()
# Out:
# /Users/chaewon/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_24 (Conv2D)              │ (None, 128, 128, 32)   │           416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 128, 128, 32)   │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 64, 64, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 64, 64, 64)     │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (None, 32, 32, 128)    │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 32, 32, 128)    │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │     8,388,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,517,825 (32.49 MB)
#  Trainable params: 8,517,377 (32.49 MB)
#  Non-trainable params: 448 (1.75 KB)
# None

# %%
history= model.fit(X_train,
                   y_train,
                   validation_split=0.2,
                   epochs=100,
                   callbacks=[early_stopping, checkpoint],
                   batch_size=32)
# Out:
# Epoch 1/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - Precision: 0.5778 - Recall: 0.5620 - accuracy: 0.5869 - auc_2: 0.6047 - loss: 6.1673
# Epoch 1: val_loss improved from inf to 0.62810, saving model to ../model/binary_model1110.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 24s 373ms/step - Precision: 0.5783 - Recall: 0.5627 - accuracy: 0.5873 - auc_2: 0.6055 - loss: 6.1021 - val_Precision: 0.6737 - val_Recall: 0.6463 - val_accuracy: 0.6503 - val_auc_2: 0.7240 - val_loss: 0.6281
# Epoch 2/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - Precision: 0.7321 - Recall: 0.7655 - accuracy: 0.7511 - auc_2: 0.8338 - loss: 0.5109
# Epoch 2: val_loss did not improve from 0.62810
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 22s 377ms/step - Precision: 0.7323 - Recall: 0.7655 - accuracy: 0.7511 - auc_2: 0.8337 - loss: 0.5108 - val_Precision: 0.9000 - val_Recall: 0.0732 - val_accuracy: 0.5096 - val_auc_2: 0.7903 - val_loss: 0.6857
# Epoch 3/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - Precision: 0.8026 - Recall: 0.8241 - accuracy: 0.8126 - auc_2: 0.8966 - loss: 0.4093
# Epoch 3: val_loss improved from 0.62810 to 0.51920, saving model to ../model/binary_model1110.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 22s 380ms/step - Precision: 0.8027 - Recall: 0.8237 - accuracy: 0.8125 - auc_2: 0.8965 - loss: 0.4095 - val_Precision: 0.9102 - val_Recall: 0.6179 - val_accuracy: 0.7676 - val_auc_2: 0.8806 - val_loss: 0.5192
# Epoch 4/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - Precision: 0.8045 - Recall: 0.8331 - accuracy: 0.8179 - auc_2: 0.9099 - loss: 0.3840
# Epoch 4: val_loss improved from 0.51920 to 0.46569, saving model to ../model/binary_model1110.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 22s 375ms/step - Precision: 0.8049 - Recall: 0.8330 - accuracy: 0.8180 - auc_2: 0.9100 - loss: 0.3838 - val_Precision: 0.9080 - val_Recall: 0.6423 - val_accuracy: 0.7783 - val_auc_2: 0.8996 - val_loss: 0.4657
# Epoch 5/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - Precision: 0.8325 - Recall: 0.8719 - accuracy: 0.8503 - auc_2: 0.9377 - loss: 0.3176
# Epoch 5: val_loss did not improve from 0.46569
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 23s 385ms/step - Precision: 0.8328 - Recall: 0.8721 - accuracy: 0.8506 - auc_2: 0.9379 - loss: 0.3174 - val_Precision: 0.9268 - val_Recall: 0.3089 - val_accuracy: 0.6247 - val_auc_2: 0.8790 - val_loss: 0.9049
# Epoch 6/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - Precision: 0.8591 - Recall: 0.8665 - accuracy: 0.8613 - auc_2: 0.9523 - loss: 0.2755
# Epoch 6: val_loss did not improve from 0.46569
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 23s 384ms/step - Precision: 0.8592 - Recall: 0.8667 - accuracy: 0.8614 - auc_2: 0.9522 - loss: 0.2756 - val_Precision: 0.9817 - val_Recall: 0.4350 - val_accuracy: 0.6994 - val_auc_2: 0.9051 - val_loss: 0.7574
# Epoch 7/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - Precision: 0.8749 - Recall: 0.8726 - accuracy: 0.8745 - auc_2: 0.9519 - loss: 0.2805
# Epoch 7: val_loss improved from 0.46569 to 0.32700, saving model to ../model/binary_model1110.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 353ms/step - Precision: 0.8747 - Recall: 0.8730 - accuracy: 0.8746 - auc_2: 0.9519 - loss: 0.2805 - val_Precision: 0.8377 - val_Recall: 0.9024 - val_accuracy: 0.8571 - val_auc_2: 0.9345 - val_loss: 0.3270
# Epoch 8/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - Precision: 0.9161 - Recall: 0.8970 - accuracy: 0.9111 - auc_2: 0.9721 - loss: 0.2149
# Epoch 8: val_loss did not improve from 0.32700
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 20s 342ms/step - Precision: 0.9160 - Recall: 0.8972 - accuracy: 0.9110 - auc_2: 0.9720 - loss: 0.2149 - val_Precision: 0.8927 - val_Recall: 0.7439 - val_accuracy: 0.8188 - val_auc_2: 0.9281 - val_loss: 0.3936
# Epoch 9/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - Precision: 0.8914 - Recall: 0.9129 - accuracy: 0.9044 - auc_2: 0.9745 - loss: 0.2027
# Epoch 9: val_loss did not improve from 0.32700
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 20s 338ms/step - Precision: 0.8915 - Recall: 0.9130 - accuracy: 0.9045 - auc_2: 0.9745 - loss: 0.2027 - val_Precision: 0.9043 - val_Recall: 0.7683 - val_accuracy: 0.8358 - val_auc_2: 0.9200 - val_loss: 0.4964
# Epoch 10/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - Precision: 0.8756 - Recall: 0.9097 - accuracy: 0.8946 - auc_2: 0.9682 - loss: 0.2289
# Epoch 10: val_loss did not improve from 0.32700
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 20s 339ms/step - Precision: 0.8757 - Recall: 0.9100 - accuracy: 0.8947 - auc_2: 0.9682 - loss: 0.2288 - val_Precision: 0.8138 - val_Recall: 0.9593 - val_accuracy: 0.8635 - val_auc_2: 0.9474 - val_loss: 0.3619
# Epoch 11/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - Precision: 0.9043 - Recall: 0.9432 - accuracy: 0.9245 - auc_2: 0.9849 - loss: 0.1575
# Epoch 11: val_loss did not improve from 0.32700
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 351ms/step - Precision: 0.9042 - Recall: 0.9431 - accuracy: 0.9244 - auc_2: 0.9848 - loss: 0.1578 - val_Precision: 0.9327 - val_Recall: 0.7886 - val_accuracy: 0.8593 - val_auc_2: 0.9401 - val_loss: 0.4418
# Epoch 12/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - Precision: 0.9197 - Recall: 0.9292 - accuracy: 0.9262 - auc_2: 0.9817 - loss: 0.1745
# Epoch 12: val_loss improved from 0.32700 to 0.28843, saving model to ../model/binary_model1110.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 357ms/step - Precision: 0.9197 - Recall: 0.9292 - accuracy: 0.9262 - auc_2: 0.9817 - loss: 0.1747 - val_Precision: 0.8911 - val_Recall: 0.8984 - val_accuracy: 0.8891 - val_auc_2: 0.9555 - val_loss: 0.2884
# Epoch 13/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - Precision: 0.9209 - Recall: 0.9494 - accuracy: 0.9352 - auc_2: 0.9871 - loss: 0.1442
# Epoch 13: val_loss did not improve from 0.28843
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 357ms/step - Precision: 0.9209 - Recall: 0.9494 - accuracy: 0.9352 - auc_2: 0.9871 - loss: 0.1444 - val_Precision: 0.9263 - val_Recall: 0.8171 - val_accuracy: 0.8699 - val_auc_2: 0.9575 - val_loss: 0.3265
# Epoch 14/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - Precision: 0.9386 - Recall: 0.9559 - accuracy: 0.9475 - auc_2: 0.9908 - loss: 0.1245
# Epoch 14: val_loss did not improve from 0.28843
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - Precision: 0.9386 - Recall: 0.9559 - accuracy: 0.9475 - auc_2: 0.9908 - loss: 0.1244 - val_Precision: 0.9177 - val_Recall: 0.9065 - val_accuracy: 0.9083 - val_auc_2: 0.9584 - val_loss: 0.3213
# Epoch 15/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - Precision: 0.9435 - Recall: 0.9598 - accuracy: 0.9530 - auc_2: 0.9914 - loss: 0.1119
# Epoch 15: val_loss did not improve from 0.28843
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - Precision: 0.9435 - Recall: 0.9597 - accuracy: 0.9529 - auc_2: 0.9914 - loss: 0.1121 - val_Precision: 0.9244 - val_Recall: 0.8943 - val_accuracy: 0.9062 - val_auc_2: 0.9596 - val_loss: 0.2991
# Epoch 16/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - Precision: 0.9354 - Recall: 0.9698 - accuracy: 0.9529 - auc_2: 0.9930 - loss: 0.1072
# Epoch 16: val_loss did not improve from 0.28843
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 357ms/step - Precision: 0.9355 - Recall: 0.9697 - accuracy: 0.9529 - auc_2: 0.9930 - loss: 0.1073 - val_Precision: 0.9091 - val_Recall: 0.8537 - val_accuracy: 0.8785 - val_auc_2: 0.9498 - val_loss: 0.3598
# Epoch 17/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - Precision: 0.9485 - Recall: 0.9565 - accuracy: 0.9536 - auc_2: 0.9913 - loss: 0.1197
# Epoch 17: val_loss did not improve from 0.28843
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - Precision: 0.9485 - Recall: 0.9565 - accuracy: 0.9536 - auc_2: 0.9913 - loss: 0.1197 - val_Precision: 0.8102 - val_Recall: 0.9715 - val_accuracy: 0.8657 - val_auc_2: 0.9547 - val_loss: 0.4569
# Epoch 18/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - Precision: 0.9443 - Recall: 0.9616 - accuracy: 0.9533 - auc_2: 0.9925 - loss: 0.1134
# Epoch 18: val_loss improved from 0.28843 to 0.28610, saving model to ../model/binary_model1110.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - Precision: 0.9444 - Recall: 0.9617 - accuracy: 0.9534 - auc_2: 0.9925 - loss: 0.1131 - val_Precision: 0.8906 - val_Recall: 0.9268 - val_accuracy: 0.9019 - val_auc_2: 0.9626 - val_loss: 0.2861
# Epoch 19/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - Precision: 0.9626 - Recall: 0.9650 - accuracy: 0.9638 - auc_2: 0.9949 - loss: 0.0938
# Epoch 19: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - Precision: 0.9625 - Recall: 0.9652 - accuracy: 0.9638 - auc_2: 0.9949 - loss: 0.0937 - val_Precision: 0.9076 - val_Recall: 0.9187 - val_accuracy: 0.9083 - val_auc_2: 0.9609 - val_loss: 0.3131
# Epoch 20/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - Precision: 0.9583 - Recall: 0.9773 - accuracy: 0.9678 - auc_2: 0.9967 - loss: 0.0760
# Epoch 20: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - Precision: 0.9582 - Recall: 0.9773 - accuracy: 0.9676 - auc_2: 0.9967 - loss: 0.0761 - val_Precision: 0.8076 - val_Recall: 0.9553 - val_accuracy: 0.8571 - val_auc_2: 0.9373 - val_loss: 0.5859
# Epoch 21/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - Precision: 0.9614 - Recall: 0.9730 - accuracy: 0.9672 - auc_2: 0.9965 - loss: 0.0750
# Epoch 21: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 354ms/step - Precision: 0.9614 - Recall: 0.9730 - accuracy: 0.9672 - auc_2: 0.9965 - loss: 0.0752 - val_Precision: 0.8731 - val_Recall: 0.9228 - val_accuracy: 0.8891 - val_auc_2: 0.9520 - val_loss: 0.3800
# Epoch 22/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - Precision: 0.9576 - Recall: 0.9611 - accuracy: 0.9587 - auc_2: 0.9954 - loss: 0.0876
# Epoch 22: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 356ms/step - Precision: 0.9576 - Recall: 0.9612 - accuracy: 0.9587 - auc_2: 0.9954 - loss: 0.0876 - val_Precision: 0.9372 - val_Recall: 0.8496 - val_accuracy: 0.8913 - val_auc_2: 0.9500 - val_loss: 0.4205
# Epoch 23/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - Precision: 0.9619 - Recall: 0.9879 - accuracy: 0.9733 - auc_2: 0.9978 - loss: 0.0625
# Epoch 23: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 22s 376ms/step - Precision: 0.9620 - Recall: 0.9879 - accuracy: 0.9733 - auc_2: 0.9978 - loss: 0.0624 - val_Precision: 0.9095 - val_Recall: 0.8984 - val_accuracy: 0.8998 - val_auc_2: 0.9451 - val_loss: 0.4293
# Epoch 24/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - Precision: 0.9585 - Recall: 0.9784 - accuracy: 0.9683 - auc_2: 0.9970 - loss: 0.0716
# Epoch 24: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 22s 372ms/step - Precision: 0.9586 - Recall: 0.9784 - accuracy: 0.9683 - auc_2: 0.9971 - loss: 0.0715 - val_Precision: 0.8481 - val_Recall: 0.9309 - val_accuracy: 0.8763 - val_auc_2: 0.9439 - val_loss: 0.5027
# Epoch 25/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - Precision: 0.9688 - Recall: 0.9900 - accuracy: 0.9789 - auc_2: 0.9988 - loss: 0.0454
# Epoch 25: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 357ms/step - Precision: 0.9688 - Recall: 0.9899 - accuracy: 0.9788 - auc_2: 0.9988 - loss: 0.0457 - val_Precision: 0.9298 - val_Recall: 0.8618 - val_accuracy: 0.8934 - val_auc_2: 0.9469 - val_loss: 0.4526
# Epoch 26/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - Precision: 0.9692 - Recall: 0.9926 - accuracy: 0.9804 - auc_2: 0.9987 - loss: 0.0482
# Epoch 26: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 359ms/step - Precision: 0.9691 - Recall: 0.9924 - accuracy: 0.9802 - auc_2: 0.9987 - loss: 0.0483 - val_Precision: 0.9434 - val_Recall: 0.8130 - val_accuracy: 0.8763 - val_auc_2: 0.9495 - val_loss: 0.4320
# Epoch 27/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - Precision: 0.9765 - Recall: 0.9850 - accuracy: 0.9804 - auc_2: 0.9990 - loss: 0.0444
# Epoch 27: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 21s 358ms/step - Precision: 0.9765 - Recall: 0.9849 - accuracy: 0.9804 - auc_2: 0.9990 - loss: 0.0445 - val_Precision: 0.9004 - val_Recall: 0.9553 - val_accuracy: 0.9211 - val_auc_2: 0.9671 - val_loss: 0.3240
# Epoch 28/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - Precision: 0.9555 - Recall: 0.9855 - accuracy: 0.9702 - auc_2: 0.9969 - loss: 0.0753
# Epoch 28: val_loss did not improve from 0.28610
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 22s 365ms/step - Precision: 0.9557 - Recall: 0.9855 - accuracy: 0.9704 - auc_2: 0.9969 - loss: 0.0749 - val_Precision: 0.9032 - val_Recall: 0.9106 - val_accuracy: 0.9019 - val_auc_2: 0.9465 - val_loss: 0.4901

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### 1. Accuracy

# %%
val_accuracy = history.history['val_accuracy']
train_accuracy = history.history['accuracy']
epochs = range(1, len(val_accuracy) + 1)

plt.plot(epochs, val_accuracy,  label=f'Val Accuracy')
plt.plot(epochs, train_accuracy, linestyle='--', label=f'Train Accuracy')

plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 2. Precision

# %%
val_precision = history.history['val_Precision']
train_precision = history.history['Precision']
epochs = range(1, len(val_precision) + 1)

plt.plot(epochs, val_precision, label='Val Precision')
plt.plot(epochs, train_precision, linestyle='--', label='Train Precision')

plt.title('Training and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 3. Recall

# %%
val_recall = history.history['val_Recall']
train_recall = history.history['Recall']
epochs = range(1, len(val_recall) + 1)

plt.plot(epochs, val_recall, label='Val Recall')
plt.plot(epochs, train_recall, linestyle='--', label='Train Recall')

plt.title('Training and Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 4. AUC

# %%
val_auc = history.history['val_auc_2']
train_auc = history.history['auc_2']
epochs = range(1, len(val_auc) + 1)

plt.plot(epochs, val_auc, label='Val AUC')
plt.plot(epochs, train_auc, linestyle='--', label='Train AUC')

plt.title('Training and Validation AUC')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 5. Confusion Matrix

# %%
y_pred = model.predict(X_test)
y_pred = (model.predict(X_test) > 0.5).astype(int)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
