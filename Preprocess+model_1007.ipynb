# %% [markdown]
# # Library install

# %%
pip install nibabel pandas numpy scipy openpyxl imageio
# Out:
# Requirement already satisfied: nibabel in c:\users\user\.conda\envs\syrr\lib\site-packages (4.0.2)
# Requirement already satisfied: pandas in c:\users\user\.conda\envs\syrr\lib\site-packages (1.3.5)
# Requirement already satisfied: numpy in c:\users\user\.conda\envs\syrr\lib\site-packages (1.21.6)
# Requirement already satisfied: scipy in c:\users\user\.conda\envs\syrr\lib\site-packages (1.7.3)
# Requirement already satisfied: openpyxl in c:\users\user\.conda\envs\syrr\lib\site-packages (3.1.3)
# Collecting imageio
#   Downloading imageio-2.31.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: packaging>=17.0 in c:\users\user\.conda\envs\syrr\lib\site-packages (from nibabel) (24.0)
# Requirement already satisfied: setuptools in c:\users\user\.conda\envs\syrr\lib\site-packages (from nibabel) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\.conda\envs\syrr\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\.conda\envs\syrr\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in c:\users\user\.conda\envs\syrr\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\user\.conda\envs\syrr\lib\site-packages (from imageio) (9.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\.conda\envs\syrr\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Downloading imageio-2.31.2-py3-none-any.whl (313 kB)
#    ---------------------------------------- 313.2/313.2 kB 9.5 MB/s eta 0:00:00
# Installing collected packages: imageio
# Successfully installed imageio-2.31.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Preprocessing

# %%
import os
import imageio
import numpy as np
import pandas as pd
from scipy.ndimage import zoom
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

####################################
## 0. 데이터 로드
####################################
# 경로 설정
excel_file_path = "C:/Users/USER/Desktop/브레이니화_딥러닝/dataset/oasis_cross-sectional-5708aa0a98d82080.xlsx"
data_dir = "C:/Users/USER/Desktop/브레이니화_딥러닝/dataset"

# 엑셀 파일에서 인구통계학적 정보를 데이터프레임으로 로드 - 모든 정보를 가져옴
df = pd.read_excel(excel_file_path)
df = df[['ID', 'M/F', 'Hand', 'Age', 'Educ', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV', 'ASF', 'Delay']]

####################################
## 1. 결측값 제거
####################################
# CDR 값이 없는 경우, 결측값으로 간주하고 제거
# dorpna() : 결측값을 처리하는 함수
df = df.dropna(subset=['CDR'])

# MRI, label, 인구통계 정보를 위한 리스트와 딕셔너리 생성
coronal_images = {}
sagittal_images = {}
transverse_images_gfc = {}
transverse_images_masked = {}
labels = []
demographics = {}

# 이미지 크기 조정 함수 정의 (이미지를 224x224로 변환)
def resize_image(image, new_shape=(224, 224)):
    current_shape = image.shape[:2]  # 2D 이미지이므로 앞의 두 차원만 사용 (높이, 너비)
    zoom_factors = [n / c for n, c in zip(new_shape, current_shape)] # 비율 차이 계산
    return zoom(image, zoom_factors) # 이미지 확대/축소 함수

# 피험자 데이터 로드 및 저장
# 먼저 12개의 디스크를 병합하여 처리
for disc_num in range(1, 13):  # 1~12 디스크 (OASIS 디스크 12개)
    disc_path = os.path.join(data_dir, f"oasis_cross-sectional_disc{disc_num}")
    
    # [디버깅] 디스크 경로가 존재하는지 확인
    if not os.path.exists(disc_path):
        print(f"Disc path does not exist: {disc_path}")
        continue
    
    for sub_folder in os.listdir(disc_path):  # disc 안의 폴더 탐색
        sub_folder_path = os.path.join(disc_path, sub_folder)
        
        if not os.path.isdir(sub_folder_path):  # [디버깅] 폴더가 아닌 경우 무시
            print(f"Skipping non-directory: {sub_folder_path}")
            continue
        
        for subject_dir in os.listdir(sub_folder_path):  # 피험자 폴더 탐색
            subject_path = os.path.join(sub_folder_path, subject_dir)
            
            if not os.path.isdir(subject_path): # [디버깅] 폴더가 아닌 경우 무시
                print(f"Skipping non-directory: {subject_path}")
                continue

            # MRI 경로 설정
            session_path = subject_path
            print(f"Processing session: {session_path}")

            if not os.path.exists(session_path): # [디버깅]
                print(f"Session path does not exist: {session_path}")
                continue

            # preprocessed 데이터 경로 (T88_111 폴더)
            t88_111_path = os.path.join(session_path, "PROCESSED", "MPRAGE", "T88_111")
            print(f"Checking T88_111 path: {t88_111_path}")

            if os.path.exists(t88_111_path):
                for file in os.listdir(t88_111_path):
                    file_path = os.path.join(t88_111_path, file)

                    # coronal 이미지 처리
                    if file.endswith("_cor_110.gif"):
                        print(f"Loading coronal .gif file: {file_path}")
                        try:
                            img = imageio.v2.imread(file_path)
                            img_resized = resize_image(img)
                            coronal_images[subject_dir] = img_resized
                        except Exception as e: # [디버깅]
                            print(f"Error loading coronal image: {e}")

                    # sagittal 이미지 처리
                    elif file.endswith("_sag_95.gif"):
                        print(f"Loading sagittal .gif file: {file_path}")
                        try:
                            img = imageio.v2.imread(file_path)
                            img_resized = resize_image(img)
                            sagittal_images[subject_dir] = img_resized
                        except Exception as e: # [디버깅]
                            print(f"Error loading sagittal image: {e}")

                    # transverse 이미지 처리
                    elif file.endswith("_tra_90.gif"):
                        if "masked_gfc" in file:
                            print(f"Loading masked transverse .gif file: {file_path}")
                            try:
                                img = imageio.v2.imread(file_path)
                                img_resized = resize_image(img)
                                transverse_images_masked[subject_dir] = img_resized
                            except Exception as e: # [디버깅]
                                print(f"Error loading masked transverse image: {e}")
                        else:
                            print(f"Loading regular transverse .gif file: {file_path}")
                            try:
                                img = imageio.v2.imread(file_path)
                                img_resized = resize_image(img)
                                transverse_images_gfc[subject_dir] = img_resized
                            except Exception as e: #[디버깅]
                                print(f"Error loading regular transverse image: {e}")

                    # 피험자 ID 그대로 추출
                    subject_id = subject_dir

                    # 엑셀에서 해당 ID를 매칭하고 정보를 찾기
                    subject_info = df[df['ID'] == subject_id]

                    if not subject_info.empty:
                        # CDR 값을 label로 사용
                        cdr_value = subject_info['CDR'].values[0]
                        labels.append(cdr_value)

                        # 인구통계학적 정보 딕셔너리에 저장
                        demographics[subject_id] = {
                            'M/F': subject_info['M/F'].values[0],
                            'Hand': subject_info['Hand'].values[0],
                            'Age': subject_info['Age'].values[0],
                            'Educ': subject_info['Educ'].values[0],
                            'SES': subject_info['SES'].values[0],
                            'MMSE': subject_info['MMSE'].values[0],
                            'eTIV': subject_info['eTIV'].values[0],
                            'nWBV': subject_info['nWBV'].values[0],
                            'ASF': subject_info['ASF'].values[0],
                            'Delay': subject_info['Delay'].values[0]
                        }
                    else:
                        print(f"Label not found for subject: {subject_id}")  # label이 없는 피험자 출력
            else:
                print(f"T88_111 path does not exist: {t88_111_path}")

# 결측값 처리: label와 mri가 동시에 존재하는 피실험자만 데이터셋으로 사용하기
valid_subjects = [subject for subject in demographics if subject in df['ID'].values]
coronal_images = {subject: coronal_images[subject] for subject in valid_subjects if subject in coronal_images}
sagittal_images = {subject: sagittal_images[subject] for subject in valid_subjects if subject in sagittal_images}
transverse_images_gfc = {subject: transverse_images_gfc[subject] for subject in valid_subjects if subject in transverse_images_gfc}
transverse_images_masked = {subject: transverse_images_masked[subject] for subject in valid_subjects if subject in transverse_images_masked}
labels = [df[df['ID'] == subject]['CDR'].values[0] for subject in valid_subjects]

# 1차 최종 정보 출력
print(f"Coronal images: {len(coronal_images)}")
print(f"Sagittal images: {len(sagittal_images)}")
print(f"Regular transverse images: {len(transverse_images_gfc)}")
print(f"Masked transverse images: {len(transverse_images_masked)}")
print(f"총 label: {len(labels)}")
print(f"저장된 피험자 수: {len(demographics)}")

####################################
## 2. Label 인코딩
####################################
def convert_images_to_array(image_dict):
    image_array = []
    for img in image_dict.values():
        # if 이미지가 흑백인 경우 : 채널을 추가하는 코드 - 모델에 입력 가능한 형태인 (height, width, 1)로 맞춤
        if len(img.shape) == 2:
            img = np.expand_dims(img, axis=-1)
        image_array.append(img)
    return np.array(image_array)

# 전체 치매군과 비치매군 인원수 출력
dementia_count = sum([1 if cdr >= 0.5 else 0 for cdr in labels])
non_dementia_count = len(labels) - dementia_count
print(f"Total Dementia: {dementia_count}, Total Non-dementia: {non_dementia_count}")

# 비치매군을 치매군의 개수에 맞게 랜덤 추출 (과적합 방지를 위해)
non_dementia_subjects = [subject for subject, cdr in zip(valid_subjects, labels) if cdr == 0]
np.random.seed(42)
non_dementia_subjects_balanced = np.random.choice(non_dementia_subjects, size=dementia_count, replace=False).tolist()

# 치매군과 밸런스맞춘 비치매군의 데이터셋을 합침
dementia_subjects = [subject for subject, cdr in zip(valid_subjects, labels) if cdr >= 0.5]
balanced_subjects = dementia_subjects + non_dementia_subjects_balanced

# label 1은 치매, label 0은 비치매로 설정
balanced_labels = [1] * len(dementia_subjects) + [0] * len(non_dementia_subjects_balanced)

####################################
## 3. 데이터셋 분리
####################################
# 데이터셋을 train/validation/test로 분할
train_subjects, temp_subjects, train_labels, temp_labels = train_test_split(
    balanced_subjects, balanced_labels, test_size=0.3, stratify=balanced_labels, random_state=42
)

val_subjects, test_subjects, val_labels, test_labels = train_test_split(
    temp_subjects, temp_labels, test_size=2/3, stratify=temp_labels, random_state=42
)

# 각 세트에 맞는 이미지들 준비 (coronal, sagittal, transverse, transverse_masked)
train_coronal = convert_images_to_array({subject: coronal_images[subject] for subject in train_subjects if subject in coronal_images})
val_coronal = convert_images_to_array({subject: coronal_images[subject] for subject in val_subjects if subject in coronal_images})
test_coronal = convert_images_to_array({subject: coronal_images[subject] for subject in test_subjects if subject in coronal_images})

train_sagittal = convert_images_to_array({subject: sagittal_images[subject] for subject in train_subjects if subject in sagittal_images})
val_sagittal = convert_images_to_array({subject: sagittal_images[subject] for subject in val_subjects if subject in sagittal_images})
test_sagittal = convert_images_to_array({subject: sagittal_images[subject] for subject in test_subjects if subject in sagittal_images})

train_transverse_gfc = convert_images_to_array({subject: transverse_images_gfc[subject] for subject in train_subjects if subject in transverse_images_gfc})
val_transverse_gfc = convert_images_to_array({subject: transverse_images_gfc[subject] for subject in val_subjects if subject in transverse_images_gfc})
test_transverse_gfc = convert_images_to_array({subject: transverse_images_gfc[subject] for subject in test_subjects if subject in transverse_images_gfc})

train_transverse_masked = convert_images_to_array({subject: transverse_images_masked[subject] for subject in train_subjects if subject in transverse_images_masked})
val_transverse_masked = convert_images_to_array({subject: transverse_images_masked[subject] for subject in val_subjects if subject in transverse_images_masked})
test_transverse_masked = convert_images_to_array({subject: transverse_images_masked[subject] for subject in test_subjects if subject in transverse_images_masked})

####################################
## 4. 정규화(Normalization)
####################################
# 정규화 함수 정의 (이미지의 픽셀 값을 0에서 1 사이로 정규화)
def normalize_image(image):
    # 이미지의 최대값이 0이 아니어야 정규화를 진행
    if image.max() > 0:
        return image / 255.0
    else:
        return image

# 정규화 적용 및 정규화 전후 값 출력 [디버깅]
def normalize_and_compare(image_array, image_type):
    print(f"Before Normalization: {image_type} Min={image_array.min()}, Max={image_array.max()}")
    normalized_images = normalize_image(image_array)
    print(f"After Normalization: {image_type} Min={normalized_images.min()}, Max={normalized_images.max()}")
    return normalized_images

# 이미지 배열에 정규화 적용
train_coronal = normalize_and_compare(train_coronal, 'Train Coronal')
val_coronal = normalize_and_compare(val_coronal, 'Validation Coronal')
test_coronal = normalize_and_compare(test_coronal, 'Test Coronal')

train_sagittal = normalize_and_compare(train_sagittal, 'Train Sagittal')
val_sagittal = normalize_and_compare(val_sagittal, 'Validation Sagittal')
test_sagittal = normalize_and_compare(test_sagittal, 'Test Sagittal')

train_transverse_gfc = normalize_and_compare(train_transverse_gfc, 'Train Transverse GFC')
val_transverse_gfc = normalize_and_compare(val_transverse_gfc, 'Validation Transverse GFC')
test_transverse_gfc = normalize_and_compare(test_transverse_gfc, 'Test Transverse GFC')

train_transverse_masked = normalize_and_compare(train_transverse_masked, 'Train Transverse Masked')
val_transverse_masked = normalize_and_compare(val_transverse_masked, 'Validation Transverse Masked')
test_transverse_masked = normalize_and_compare(test_transverse_masked, 'Test Transverse Masked')

# 최종 데이터셋 출력
print(f"Train set: {len(train_subjects)} subjects (Dementia: {sum(train_labels)}, Non-dementia: {len(train_labels) - sum(train_labels)})")
print(f"Validation set: {len(val_subjects)} subjects (Dementia: {sum(val_labels)}, Non-dementia: {len(val_labels) - sum(val_labels)})")
print(f"Test set: {len(test_subjects)} subjects (Dementia: {sum(test_labels)}, Non-dementia: {len(test_labels) - sum(test_labels)})")
# Out:
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0001_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0001_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0001_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0001_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0001_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0001_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0001_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0001_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0001_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0001_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0002_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0002_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0002_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0002_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0002_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0002_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0002_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0002_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0002_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0002_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0003_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0003_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0003_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0003_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0003_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0003_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0003_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0003_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0003_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0003_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0004_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0004_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0004_MR1
# Label not found for subject: OAS1_0004_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0004_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0004_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0004_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0004_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0004_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0004_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0004_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0004_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0004_MR1
# Label not found for subject: OAS1_0004_MR1
# Label not found for subject: OAS1_0004_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0004_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0004_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0004_MR1
# Label not found for subject: OAS1_0004_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0005_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0005_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0005_MR1
# Label not found for subject: OAS1_0005_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0005_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0005_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0005_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0005_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0005_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0005_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0005_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0005_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0005_MR1
# Label not found for subject: OAS1_0005_MR1
# Label not found for subject: OAS1_0005_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0005_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0005_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0005_MR1
# Label not found for subject: OAS1_0005_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0006_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0006_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0006_MR1
# Label not found for subject: OAS1_0006_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0006_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0006_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0006_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0006_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0006_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0006_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0006_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0006_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0006_MR1
# Label not found for subject: OAS1_0006_MR1
# Label not found for subject: OAS1_0006_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0006_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0006_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0006_MR1
# Label not found for subject: OAS1_0006_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0007_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0007_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0007_MR1
# Label not found for subject: OAS1_0007_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0007_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0007_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0007_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0007_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0007_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0007_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0007_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0007_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0007_MR1
# Label not found for subject: OAS1_0007_MR1
# Label not found for subject: OAS1_0007_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0007_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0007_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0007_MR1
# Label not found for subject: OAS1_0007_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0009_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0009_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0009_MR1
# Label not found for subject: OAS1_0009_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0009_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0009_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0009_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0009_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0009_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0009_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0009_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0009_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0009_MR1
# Label not found for subject: OAS1_0009_MR1
# Label not found for subject: OAS1_0009_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0009_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0009_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0009_MR1
# Label not found for subject: OAS1_0009_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0010_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0010_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0010_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0010_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0010_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0010_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0010_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0010_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0010_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0010_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0011_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0011_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0011_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0011_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0011_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0011_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0011_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0011_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0011_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0011_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0012_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0012_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0012_MR1
# Label not found for subject: OAS1_0012_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0012_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0012_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0012_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0012_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0012_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0012_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0012_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0012_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0012_MR1
# Label not found for subject: OAS1_0012_MR1
# Label not found for subject: OAS1_0012_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0012_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0012_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0012_MR1
# Label not found for subject: OAS1_0012_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0013_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0013_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0013_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0013_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0013_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0013_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0013_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0013_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0013_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0013_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0014_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0014_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0014_MR1
# Label not found for subject: OAS1_0014_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0014_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0014_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0014_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0014_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0014_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0014_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0014_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0014_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0014_MR1
# Label not found for subject: OAS1_0014_MR1
# Label not found for subject: OAS1_0014_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0014_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0014_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0014_MR1
# Label not found for subject: OAS1_0014_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0015_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0015_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0015_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0015_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0015_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0015_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0015_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0015_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0015_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0015_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0016_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0016_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0016_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0016_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0016_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0016_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0016_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0016_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0016_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0016_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0017_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0017_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0017_MR1
# Label not found for subject: OAS1_0017_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0017_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0017_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0017_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0017_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0017_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0017_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0017_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0017_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0017_MR1
# Label not found for subject: OAS1_0017_MR1
# Label not found for subject: OAS1_0017_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0017_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0017_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0017_MR1
# Label not found for subject: OAS1_0017_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0018_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0018_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0018_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0018_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0018_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0018_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0018_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0018_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0018_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0018_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0019_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0019_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0019_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0019_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0019_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0019_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0019_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0019_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0019_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0019_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0020_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0020_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0020_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0020_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0020_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0020_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0020_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0020_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0020_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0020_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0021_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0021_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0021_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0021_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0021_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0021_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0021_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0021_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0021_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0021_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0022_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0022_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0022_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0022_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0022_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0022_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0022_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0022_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0022_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0022_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0023_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0023_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0023_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0023_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0023_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0023_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0023_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0023_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0023_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0023_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0025_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0025_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0025_MR1
# Label not found for subject: OAS1_0025_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0025_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0025_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0025_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0025_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0025_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0025_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0025_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0025_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0025_MR1
# Label not found for subject: OAS1_0025_MR1
# Label not found for subject: OAS1_0025_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0025_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0025_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0025_MR1
# Label not found for subject: OAS1_0025_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0026_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0026_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0026_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0026_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0026_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0026_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0026_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0026_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0026_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0026_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0027_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0027_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0027_MR1
# Label not found for subject: OAS1_0027_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0027_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0027_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0027_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0027_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0027_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0027_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0027_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0027_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0027_MR1
# Label not found for subject: OAS1_0027_MR1
# Label not found for subject: OAS1_0027_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0027_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0027_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0027_MR1
# Label not found for subject: OAS1_0027_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0028_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0028_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0028_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0028_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0028_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0028_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0028_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0028_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0028_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0028_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0029_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0029_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0029_MR1
# Label not found for subject: OAS1_0029_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0029_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0029_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0029_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0029_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0029_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0029_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0029_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0029_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0029_MR1
# Label not found for subject: OAS1_0029_MR1
# Label not found for subject: OAS1_0029_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0029_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0029_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0029_MR1
# Label not found for subject: OAS1_0029_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0030_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0030_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0030_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0030_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0030_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0030_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0030_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0030_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0030_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0030_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0031_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0031_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0031_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0031_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0031_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0031_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0031_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0031_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0031_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0031_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0032_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0032_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0032_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0032_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0032_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0032_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0032_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0032_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0032_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0032_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0033_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0033_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0033_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0033_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0033_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0033_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0033_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0033_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0033_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0033_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0034_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0034_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0034_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0034_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0034_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0034_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0034_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0034_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0034_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0034_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0035_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0035_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0035_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0035_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0035_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0035_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0035_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0035_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0035_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0035_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0037_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0037_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0037_MR1
# Label not found for subject: OAS1_0037_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0037_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0037_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0037_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0037_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0037_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0037_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0037_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0037_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0037_MR1
# Label not found for subject: OAS1_0037_MR1
# Label not found for subject: OAS1_0037_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0037_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0037_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0037_MR1
# Label not found for subject: OAS1_0037_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0038_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0038_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0038_MR1
# Label not found for subject: OAS1_0038_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0038_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0038_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0038_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0038_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0038_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0038_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0038_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0038_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0038_MR1
# Label not found for subject: OAS1_0038_MR1
# Label not found for subject: OAS1_0038_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0038_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0038_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0038_MR1
# Label not found for subject: OAS1_0038_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0039_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0039_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0039_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0039_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0039_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0039_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0039_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0039_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0039_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0039_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0040_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0040_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0040_MR1
# Label not found for subject: OAS1_0040_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0040_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0040_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0040_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0040_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0040_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0040_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0040_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0040_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0040_MR1
# Label not found for subject: OAS1_0040_MR1
# Label not found for subject: OAS1_0040_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0040_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0040_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0040_MR1
# Label not found for subject: OAS1_0040_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0041_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0041_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0041_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0041_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0041_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0041_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0041_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0041_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0041_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0041_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0042_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0042_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0042_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0042_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0042_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0042_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0042_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0042_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc1\disc1\OAS1_0042_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0042_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0043_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0043_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0043_MR1
# Label not found for subject: OAS1_0043_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0043_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0043_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0043_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0043_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0043_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0043_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0043_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0043_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0043_MR1
# Label not found for subject: OAS1_0043_MR1
# Label not found for subject: OAS1_0043_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0043_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0043_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0043_MR1
# Label not found for subject: OAS1_0043_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0044_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0044_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0044_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0044_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0044_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0044_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc2\disc2\OAS1_0044_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0044_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# ...
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0445_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0445_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0445_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0445_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0445_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0445_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0445_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0445_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0446_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0446_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0446_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0446_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0446_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0446_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0446_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0446_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0446_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0446_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0447_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0447_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0447_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0447_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0447_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0447_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0447_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0447_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0447_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0447_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0448_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0448_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0448_MR1
# Label not found for subject: OAS1_0448_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0448_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0448_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0448_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0448_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0448_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0448_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0448_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0448_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0448_MR1
# Label not found for subject: OAS1_0448_MR1
# Label not found for subject: OAS1_0448_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0448_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0448_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0448_MR1
# Label not found for subject: OAS1_0448_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0449_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0449_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0449_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0449_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0449_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0449_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0449_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0449_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0449_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0449_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0450_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0450_MR1\PROCESSED\MPRAGE\T88_111
# Label not found for subject: OAS1_0450_MR1
# Label not found for subject: OAS1_0450_MR1
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0450_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0450_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Label not found for subject: OAS1_0450_MR1
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0450_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0450_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Label not found for subject: OAS1_0450_MR1
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0450_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0450_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Label not found for subject: OAS1_0450_MR1
# Label not found for subject: OAS1_0450_MR1
# Label not found for subject: OAS1_0450_MR1
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0450_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0450_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Label not found for subject: OAS1_0450_MR1
# Label not found for subject: OAS1_0450_MR1
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0451_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0451_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0451_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0451_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0451_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0451_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0451_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0451_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0451_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0451_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0452_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0452_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0452_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0452_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0452_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0452_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0452_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0452_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0452_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0452_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0453_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0453_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0453_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0453_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0453_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0453_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0453_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0453_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0453_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0453_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0454_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0454_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0454_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0454_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0454_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0454_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0454_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0454_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0454_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0454_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0455_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0455_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0455_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0455_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0455_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0455_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0455_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0455_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0455_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0455_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0456_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0456_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0456_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0456_MR1_mpr_n4_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0456_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0456_MR1_mpr_n4_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0456_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0456_MR1_mpr_n4_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0456_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0456_MR1_mpr_n4_anon_111_t88_masked_gfc_tra_90.gif
# Processing session: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0457_MR1
# Checking T88_111 path: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0457_MR1\PROCESSED\MPRAGE\T88_111
# Loading coronal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0457_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0457_MR1_mpr_n3_anon_111_t88_gfc_cor_110.gif
# Loading sagittal .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0457_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0457_MR1_mpr_n3_anon_111_t88_gfc_sag_95.gif
# Loading regular transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0457_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0457_MR1_mpr_n3_anon_111_t88_gfc_tra_90.gif
# Loading masked transverse .gif file: C:/Users/USER/Desktop/브레이니화_딥러닝/dataset\oasis_cross-sectional_disc12\disc12\OAS1_0457_MR1\PROCESSED\MPRAGE\T88_111\OAS1_0457_MR1_mpr_n3_anon_111_t88_masked_gfc_tra_90.gif
# Coronal images: 230
# Sagittal images: 230
# Regular transverse images: 230
# Masked transverse images: 230
# 총 label: 230
# 저장된 피험자 수: 230
# Total Dementia: 96, Total Non-dementia: 134
# Before Normalization: Train Coronal Min=0, Max=255
# After Normalization: Train Coronal Min=0.0, Max=1.0
# Before Normalization: Validation Coronal Min=0, Max=251
# After Normalization: Validation Coronal Min=0.0, Max=0.984313725490196
# Before Normalization: Test Coronal Min=0, Max=255
# After Normalization: Test Coronal Min=0.0, Max=1.0
# Before Normalization: Train Sagittal Min=0, Max=243
# After Normalization: Train Sagittal Min=0.0, Max=0.9529411764705882
# Before Normalization: Validation Sagittal Min=0, Max=236
# After Normalization: Validation Sagittal Min=0.0, Max=0.9254901960784314
# Before Normalization: Test Sagittal Min=0, Max=248
# After Normalization: Test Sagittal Min=0.0, Max=0.9725490196078431
# Before Normalization: Train Transverse GFC Min=0, Max=243
# After Normalization: Train Transverse GFC Min=0.0, Max=0.9529411764705882
# Before Normalization: Validation Transverse GFC Min=0, Max=231
# After Normalization: Validation Transverse GFC Min=0.0, Max=0.9058823529411765
# Before Normalization: Test Transverse GFC Min=0, Max=232
# After Normalization: Test Transverse GFC Min=0.0, Max=0.9098039215686274
# Before Normalization: Train Transverse Masked Min=0, Max=201
# After Normalization: Train Transverse Masked Min=0.0, Max=0.788235294117647
# Before Normalization: Validation Transverse Masked Min=0, Max=170
# After Normalization: Validation Transverse Masked Min=0.0, Max=0.6666666666666666
# Before Normalization: Test Transverse Masked Min=0, Max=198
# After Normalization: Test Transverse Masked Min=0.0, Max=0.7764705882352941
# Train set: 134 subjects (Dementia: 67, Non-dementia: 67)
# Validation set: 19 subjects (Dementia: 10, Non-dementia: 9)
# Test set: 39 subjects (Dementia: 19, Non-dementia: 20)

# %% [markdown]
# # Visualising

# %%
import matplotlib.pyplot as plt

# 이미지 시각화 함수 정의
def display_sample_images(image_arrays, titles, cmap='gray'):
    # 이미지 배열과 제목 리스트의 길이가 같아야 함
    assert len(image_arrays) == len(titles)
    
    plt.figure(figsize=(15, 5))
    for i, (image, title) in enumerate(zip(image_arrays, titles)):
        plt.subplot(1, len(image_arrays), i+1)
        plt.imshow(image.squeeze(), cmap=cmap)
        plt.title(title)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# 샘플 이미지를 시각화 (정규화된 이미지 확인)
def visualize_samples():
    # Coronal, Sagittal, Transverse 2종 각각 첫 번째 샘플 이미지 시각화
    sample_coronal = [train_coronal[0], val_coronal[0], test_coronal[0]]
    sample_sagittal = [train_sagittal[0], val_sagittal[0], test_sagittal[0]]
    sample_transverse_gfc = [train_transverse_gfc[0], val_transverse_gfc[0], test_transverse_gfc[0]]
    sample_transverse_masked = [train_transverse_masked[0], val_transverse_masked[0], test_transverse_masked[0]]
    
    # Coronal 이미지 시각화
    display_sample_images(sample_coronal, ["Train Coronal", "Validation Coronal", "Test Coronal"])
    
    # Sagittal 이미지 시각화
    display_sample_images(sample_sagittal, ["Train Sagittal", "Validation Sagittal", "Test Sagittal"])
    
    # Transverse GFC 이미지 시각화
    display_sample_images(sample_transverse_gfc, ["Train Transverse GFC", "Validation Transverse GFC", "Test Transverse GFC"])
    
    # Transverse Masked 이미지 시각화
    display_sample_images(sample_transverse_masked, ["Train Transverse Masked", "Validation Transverse Masked", "Test Transverse Masked"])

# 샘플 이미지 시각화 실행
visualize_samples()

# %% [markdown]
# # Graphs for Final Dataset

# %%
import matplotlib.pyplot as plt

# 인구통계 정보에서 가져오기
demographic_data = pd.DataFrame.from_dict(demographics, orient='index')

# 성별
gender_counts = demographic_data['M/F'].value_counts()

# 치매 여부 분포 (CDR 값이 0인 경우 비치매, 0.5 이상인 경우 치매)
dementia_counts = pd.Series({
    'Non-dementia': len([cdr for cdr in labels if cdr == 0]),
    'Dementia': len([cdr for cdr in labels if cdr >= 0.5])
})
# 그래프 그리기
plt.figure(figsize=(10, 5))

# 성별 분포 그래프
plt.subplot(1, 2, 1)
gender_counts.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Gender Distribution')
plt.ylabel('Number of Subjects')
plt.xticks(rotation=0)

# 치매 여부 분포 그래프
plt.subplot(1, 2, 2)
dementia_counts.plot(kind='bar', color=['lightgreen', 'orange'])
plt.title('Dementia vs Non-dementia')
plt.ylabel('Number of Subjects')
plt.xticks(rotation=0)

# 그래프 표시
plt.tight_layout()
plt.show()

# 치매 (CDR >= 0.5)와 비치매 (CDR == 0) 그룹 나누기
dementia_group = demographic_data.loc[[subject for subject, label in zip(demographic_data.index, labels) if label >= 0.5]]
non_dementia_group = demographic_data.loc[[subject for subject, label in zip(demographic_data.index, labels) if label == 0]]

# 박스플롯으로 각 변수 (Age, Educ, MMSE, eTIV, nWBV, ASF) 시각화
plt.figure(figsize=(15, 10))

variables = ['Age', 'Educ', 'MMSE', 'eTIV', 'nWBV', 'ASF']
for i, var in enumerate(variables, 1):
    plt.subplot(2, 3, i)
    plt.boxplot([non_dementia_group[var].dropna(), dementia_group[var].dropna()], labels=['Non-dementia', 'Dementia'])
    plt.title(f'{var} Distribution by Dementia Status')
    plt.ylabel(var)

plt.tight_layout()
plt.show()

# %% [markdown]
# # GPU activation

# %%
import os
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = '0' # 여러개 사용시 '0,1,2' 식으로 하나의 문자열에 입력
gpus = tf.config.experimental.list_physical_devices('GPU') # 호스트 러나임에 표시되는 GPU 장치 목록 반환

if gpus: # 반환된 GPU 장치 목록이 있다면
    try: # 해당 장치에 대한 메모리 증가 활성화 여부 설정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e: # try문 실패시에 에러문구 출력
        print(e)

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # pickle

# %%
import pickle

# 전처리된 데이터를 딕셔너리에 저장
data_to_save = {
    'train_coronal': train_coronal,
    'val_coronal': val_coronal,
    'test_coronal': test_coronal,
    'train_sagittal': train_sagittal,
    'val_sagittal': val_sagittal,
    'test_sagittal': test_sagittal,
    'train_transverse_gfc': train_transverse_gfc,
    'val_transverse_gfc': val_transverse_gfc,
    'test_transverse_gfc': test_transverse_gfc,
    'train_transverse_masked': train_transverse_masked,
    'val_transverse_masked': val_transverse_masked,
    'test_transverse_masked': test_transverse_masked,
    'train_labels': train_labels,
    'val_labels': val_labels,
    'test_labels': test_labels
}

# 데이터를 pickle 파일로 저장
with open('preprocessed_dataset1007.pkl', 'wb') as f:
    pickle.dump(data_to_save, f)

print("데이터가 'preprocessed_dataset.pkl' 파일로 저장되었습니다.")
# Out:
# 데이터가 'preprocessed_dataset.pkl' 파일로 저장되었습니다.

# %% [markdown]
# # pickle load

# %%
import pickle

# pickle 파일로부터 데이터 로드
with open('preprocessed_dataset1007.pkl', 'rb') as f:
    loaded_data = pickle.load(f)

# 로드된 데이터를 필요한 변수에 할당
train_coronal = loaded_data['train_coronal']
val_coronal = loaded_data['val_coronal']
test_coronal = loaded_data['test_coronal']
train_sagittal = loaded_data['train_sagittal']
val_sagittal = loaded_data['val_sagittal']
test_sagittal = loaded_data['test_sagittal']
train_transverse_gfc = loaded_data['train_transverse_gfc']
val_transverse_gfc = loaded_data['val_transverse_gfc']
test_transverse_gfc = loaded_data['test_transverse_gfc']
train_transverse_masked = loaded_data['train_transverse_masked']
val_transverse_masked = loaded_data['val_transverse_masked']
test_transverse_masked = loaded_data['test_transverse_masked']
train_labels = loaded_data['train_labels']
val_labels = loaded_data['val_labels']
test_labels = loaded_data['test_labels']

print("데이터가 'preprocessed_dataset.pkl' 파일로부터 로드되었습니다.")
# Out:
# 데이터가 'preprocessed_dataset.pkl' 파일로부터 로드되었습니다.

# %% [markdown]
# # 모델 1
# https://github.com/clin-projects/MRI-alzheimers-classification-OASIS1-/blob/master/oasis-alzheimer-regression.ipynb

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization
from keras.optimizers import Adam
import numpy as np
####################################
## 5. 데이터 준비
####################################
# Transverse와 Masked Transverse 데이터를 준비합니다.

# Transverse 데이터 평탄화
X_train_transverse = train_transverse_gfc.reshape(train_transverse_gfc.shape[0], -1)
X_val_transverse = val_transverse_gfc.reshape(val_transverse_gfc.shape[0], -1)
X_test_transverse = test_transverse_gfc.reshape(test_transverse_gfc.shape[0], -1)

# Masked Transverse 데이터 평탄화
X_train_masked = train_transverse_masked.reshape(train_transverse_masked.shape[0], -1)
X_val_masked = val_transverse_masked.reshape(val_transverse_masked.shape[0], -1)
X_test_masked = test_transverse_masked.reshape(test_transverse_masked.shape[0], -1)

# 레이블은 동일하므로 재사용
Y_train = np.eye(2)[train_labels]
Y_val = np.eye(2)[val_labels]
Y_test = np.eye(2)[test_labels]

####################################
## 6. 모델 정의 함수 (수정된 부분)
####################################
def create_model(input_dim):
    model = Sequential()
    model.add(Dense(12, input_dim=input_dim, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(2, activation='softmax'))  # 2개의 클래스 (치매, 비치매)

    adam = Adam(learning_rate=0.0001)  # lr 대신 learning_rate 사용
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model


####################################
## 7. Transverse 데이터 학습
####################################
model_transverse = create_model(X_train_transverse.shape[1])
history_transverse = model_transverse.fit(
    X_train_transverse, Y_train, validation_data=(X_val_transverse, Y_val),
    epochs=200, batch_size=43, verbose=1
)

# 테스트 평가
test_loss_transverse, test_acc_transverse = model_transverse.evaluate(X_test_transverse, Y_test, verbose=2)
print(f"Transverse Test Accuracy: {test_acc_transverse}")

####################################
## 8. Masked Transverse 데이터 학습
####################################
model_masked = create_model(X_train_masked.shape[1])
history_masked = model_masked.fit(
    X_train_masked, Y_train, validation_data=(X_val_masked, Y_val),
    epochs=200, batch_size=43, verbose=1
)

# 테스트 평가
test_loss_masked, test_acc_masked = model_masked.evaluate(X_test_masked, Y_test, verbose=2)
print(f"Masked Transverse Test Accuracy: {test_acc_masked}")

####################################
## 9. 정확도 및 로스 그래프 그리기
####################################
# 학습 정확도와 손실을 시각화
def plot_history(histories, title):
    plt.figure(figsize=(10, 5))

    # 정확도
    plt.subplot(1, 2, 1)
    for name, history in histories:
        plt.plot(history.history['accuracy'], label=f'{name} Train')
        plt.plot(history.history['val_accuracy'], label=f'{name} Val')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # 손실
    plt.subplot(1, 2, 2)
    for name, history in histories:
        plt.plot(history.history['loss'], label=f'{name} Train')
        plt.plot(history.history['val_loss'], label=f'{name} Val')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# 두 모델의 학습 결과를 시각화
plot_history(
    [('Transverse', history_transverse), ('Masked Transverse', history_masked)],
    'Comparison of Transverse and Masked Transverse'
)
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E52CAA7F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E52CAA7F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/4 [=====================>........] - ETA: 0s - loss: 0.8156 - accuracy: 0.5426WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E52CB6BE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E52CB6BE58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 1s 94ms/step - loss: 0.8111 - accuracy: 0.5448 - val_loss: 0.8187 - val_accuracy: 0.4737
# Epoch 2/200
# 4/4 [==============================] - 0s 44ms/step - loss: 0.4425 - accuracy: 0.7761 - val_loss: 0.9513 - val_accuracy: 0.4737
# Epoch 3/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.3853 - accuracy: 0.8507 - val_loss: 1.2143 - val_accuracy: 0.4737
# Epoch 4/200
# 4/4 [==============================] - 0s 36ms/step - loss: 0.3197 - accuracy: 0.8806 - val_loss: 1.2000 - val_accuracy: 0.4737
# Epoch 5/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2679 - accuracy: 0.9627 - val_loss: 0.9903 - val_accuracy: 0.4737
# Epoch 6/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2597 - accuracy: 0.9552 - val_loss: 0.7411 - val_accuracy: 0.5263
# Epoch 7/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.2081 - accuracy: 0.9776 - val_loss: 0.6543 - val_accuracy: 0.5263
# Epoch 8/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1866 - accuracy: 0.9851 - val_loss: 0.6499 - val_accuracy: 0.5789
# Epoch 9/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1707 - accuracy: 0.9925 - val_loss: 0.6582 - val_accuracy: 0.4737
# Epoch 10/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1560 - accuracy: 1.0000 - val_loss: 0.6951 - val_accuracy: 0.5263
# Epoch 11/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1321 - accuracy: 1.0000 - val_loss: 0.7255 - val_accuracy: 0.5789
# Epoch 12/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1362 - accuracy: 1.0000 - val_loss: 0.6952 - val_accuracy: 0.5263
# Epoch 13/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1161 - accuracy: 1.0000 - val_loss: 0.6607 - val_accuracy: 0.5789
# Epoch 14/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1047 - accuracy: 1.0000 - val_loss: 0.6771 - val_accuracy: 0.5263
# Epoch 15/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1038 - accuracy: 1.0000 - val_loss: 0.6833 - val_accuracy: 0.5263
# Epoch 16/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0970 - accuracy: 1.0000 - val_loss: 0.6872 - val_accuracy: 0.5263
# Epoch 17/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0816 - accuracy: 1.0000 - val_loss: 0.7121 - val_accuracy: 0.5263
# Epoch 18/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0854 - accuracy: 1.0000 - val_loss: 0.7436 - val_accuracy: 0.4211
# Epoch 19/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0777 - accuracy: 1.0000 - val_loss: 0.7333 - val_accuracy: 0.4737
# Epoch 20/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 0.7232 - val_accuracy: 0.4737
# Epoch 21/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0699 - accuracy: 1.0000 - val_loss: 0.7159 - val_accuracy: 0.5263
# Epoch 22/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0726 - accuracy: 1.0000 - val_loss: 0.6885 - val_accuracy: 0.6316
# Epoch 23/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0855 - accuracy: 1.0000 - val_loss: 0.7116 - val_accuracy: 0.5789
# Epoch 24/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 0.7833 - val_accuracy: 0.4211
# Epoch 25/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0752 - accuracy: 1.0000 - val_loss: 0.7912 - val_accuracy: 0.4737
# Epoch 26/200
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.7501 - val_accuracy: 0.5263
# Epoch 27/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0661 - accuracy: 1.0000 - val_loss: 0.7197 - val_accuracy: 0.5789
# Epoch 28/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.7253 - val_accuracy: 0.5789
# Epoch 29/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0772 - accuracy: 1.0000 - val_loss: 0.7937 - val_accuracy: 0.4211
# Epoch 30/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0671 - accuracy: 1.0000 - val_loss: 0.8525 - val_accuracy: 0.4737
# Epoch 31/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.7875 - val_accuracy: 0.4211
# Epoch 32/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0623 - accuracy: 1.0000 - val_loss: 0.7687 - val_accuracy: 0.5263
# Epoch 33/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0589 - accuracy: 1.0000 - val_loss: 0.7487 - val_accuracy: 0.5789
# Epoch 34/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0607 - accuracy: 1.0000 - val_loss: 0.7546 - val_accuracy: 0.5789
# Epoch 35/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0738 - accuracy: 1.0000 - val_loss: 0.7655 - val_accuracy: 0.5789
# Epoch 36/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.7413 - val_accuracy: 0.5263
# Epoch 37/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.7400 - val_accuracy: 0.5789
# Epoch 38/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 0.7457 - val_accuracy: 0.5263
# Epoch 39/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0575 - accuracy: 1.0000 - val_loss: 0.7450 - val_accuracy: 0.5263
# Epoch 40/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0563 - accuracy: 1.0000 - val_loss: 0.7431 - val_accuracy: 0.5789
# Epoch 41/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.7461 - val_accuracy: 0.5789
# Epoch 42/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0790 - accuracy: 0.9851 - val_loss: 0.7999 - val_accuracy: 0.4211
# Epoch 43/200
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.8932 - val_accuracy: 0.4211
# Epoch 44/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0744 - accuracy: 1.0000 - val_loss: 0.8437 - val_accuracy: 0.5789
# Epoch 45/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0879 - accuracy: 0.9925 - val_loss: 0.8773 - val_accuracy: 0.5263
# Epoch 46/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0938 - accuracy: 0.9925 - val_loss: 0.9401 - val_accuracy: 0.4737
# Epoch 47/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0819 - accuracy: 0.9925 - val_loss: 0.9489 - val_accuracy: 0.4737
# Epoch 48/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0798 - accuracy: 0.9925 - val_loss: 0.8990 - val_accuracy: 0.4737
# Epoch 49/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0696 - accuracy: 1.0000 - val_loss: 0.8937 - val_accuracy: 0.4737
# Epoch 50/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0649 - accuracy: 1.0000 - val_loss: 0.9325 - val_accuracy: 0.4737
# Epoch 51/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0668 - accuracy: 1.0000 - val_loss: 0.8857 - val_accuracy: 0.5263
# Epoch 52/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0746 - accuracy: 1.0000 - val_loss: 0.8342 - val_accuracy: 0.5263
# Epoch 53/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0641 - accuracy: 1.0000 - val_loss: 0.8800 - val_accuracy: 0.4737
# Epoch 54/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0607 - accuracy: 1.0000 - val_loss: 0.8620 - val_accuracy: 0.5263
# Epoch 55/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 0.8539 - val_accuracy: 0.5789
# Epoch 56/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0601 - accuracy: 1.0000 - val_loss: 0.8312 - val_accuracy: 0.5263
# Epoch 57/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 0.9021 - val_accuracy: 0.5263
# Epoch 58/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0661 - accuracy: 1.0000 - val_loss: 0.8478 - val_accuracy: 0.5263
# Epoch 59/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 1.6475 - val_accuracy: 0.5263
# Epoch 60/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 1.6451 - val_accuracy: 0.5263
# Epoch 61/200
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0663 - accuracy: 1.0000 - val_loss: 1.0305 - val_accuracy: 0.4211
# Epoch 62/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 0.8072 - val_accuracy: 0.5789
# Epoch 63/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0809 - accuracy: 0.9925 - val_loss: 0.8696 - val_accuracy: 0.5789
# Epoch 64/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.8634 - val_accuracy: 0.4737
# Epoch 65/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0583 - accuracy: 1.0000 - val_loss: 0.8362 - val_accuracy: 0.5263
# Epoch 66/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0823 - accuracy: 1.0000 - val_loss: 0.8383 - val_accuracy: 0.5789
# Epoch 67/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0553 - accuracy: 1.0000 - val_loss: 1.0259 - val_accuracy: 0.4737
# Epoch 68/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 1.0410 - val_accuracy: 0.4737
# Epoch 69/200
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0580 - accuracy: 1.0000 - val_loss: 0.8929 - val_accuracy: 0.5789
# Epoch 70/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0554 - accuracy: 1.0000 - val_loss: 0.8829 - val_accuracy: 0.5263
# Epoch 71/200
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0475 - accuracy: 1.0000 - val_loss: 0.9656 - val_accuracy: 0.5263
# Epoch 72/200
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.9935 - val_accuracy: 0.5263
# Epoch 73/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.9466 - val_accuracy: 0.5263
# Epoch 74/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 0.9285 - val_accuracy: 0.5263
# Epoch 75/200
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.9243 - val_accuracy: 0.5263
# Epoch 76/200
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.8766 - val_accuracy: 0.4737
# Epoch 77/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.9374 - val_accuracy: 0.5263
# Epoch 78/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.9914 - val_accuracy: 0.5263
# Epoch 79/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0468 - accuracy: 1.0000 - val_loss: 0.9667 - val_accuracy: 0.5263
# Epoch 80/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0456 - accuracy: 1.0000 - val_loss: 0.9364 - val_accuracy: 0.5263
# Epoch 81/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0496 - accuracy: 1.0000 - val_loss: 0.9253 - val_accuracy: 0.5263
# Epoch 82/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.9211 - val_accuracy: 0.5263
# Epoch 83/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0457 - accuracy: 1.0000 - val_loss: 0.9452 - val_accuracy: 0.5263
# Epoch 84/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0407 - accuracy: 1.0000 - val_loss: 0.9687 - val_accuracy: 0.5263
# Epoch 85/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0463 - accuracy: 1.0000 - val_loss: 0.9814 - val_accuracy: 0.5789
# Epoch 86/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0404 - accuracy: 1.0000 - val_loss: 0.9788 - val_accuracy: 0.5263
# Epoch 87/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0398 - accuracy: 1.0000 - val_loss: 1.0018 - val_accuracy: 0.5263
# Epoch 88/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0503 - accuracy: 1.0000 - val_loss: 1.0184 - val_accuracy: 0.5263
# Epoch 89/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0446 - accuracy: 1.0000 - val_loss: 0.9869 - val_accuracy: 0.5263
# Epoch 90/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.9947 - val_accuracy: 0.5789
# Epoch 91/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 1.0254 - val_accuracy: 0.5263
# Epoch 92/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 1.0222 - val_accuracy: 0.5263
# Epoch 93/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0587 - accuracy: 1.0000 - val_loss: 1.0032 - val_accuracy: 0.5263
# Epoch 94/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0404 - accuracy: 1.0000 - val_loss: 1.0088 - val_accuracy: 0.5789
# Epoch 95/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 1.0130 - val_accuracy: 0.5789
# Epoch 96/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.9891 - val_accuracy: 0.5263
# Epoch 97/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 1.0050 - val_accuracy: 0.5789
# Epoch 98/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0374 - accuracy: 1.0000 - val_loss: 1.0154 - val_accuracy: 0.5789
# Epoch 99/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0410 - accuracy: 1.0000 - val_loss: 1.0155 - val_accuracy: 0.5789
# Epoch 100/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 1.0226 - val_accuracy: 0.5789
# Epoch 101/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0410 - accuracy: 1.0000 - val_loss: 1.0440 - val_accuracy: 0.5263
# Epoch 102/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 1.1086 - val_accuracy: 0.5263
# Epoch 103/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 1.1350 - val_accuracy: 0.5263
# Epoch 104/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 1.1453 - val_accuracy: 0.5263
# Epoch 105/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 1.1412 - val_accuracy: 0.5263
# Epoch 106/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0391 - accuracy: 1.0000 - val_loss: 1.0924 - val_accuracy: 0.5263
# Epoch 107/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 1.0397 - val_accuracy: 0.5789
# Epoch 108/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0641 - accuracy: 0.9776 - val_loss: 0.9031 - val_accuracy: 0.5263
# Epoch 109/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 0.9304 - val_accuracy: 0.5263
# Epoch 110/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1138 - accuracy: 1.0000 - val_loss: 1.1179 - val_accuracy: 0.5263
# Epoch 111/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1202 - accuracy: 0.9925 - val_loss: 1.0222 - val_accuracy: 0.5263
# Epoch 112/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1112 - accuracy: 0.9925 - val_loss: 0.9324 - val_accuracy: 0.5789
# Epoch 113/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1168 - accuracy: 1.0000 - val_loss: 0.8494 - val_accuracy: 0.4737
# Epoch 114/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1055 - accuracy: 1.0000 - val_loss: 0.8691 - val_accuracy: 0.5263
# Epoch 115/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1030 - accuracy: 1.0000 - val_loss: 0.8843 - val_accuracy: 0.5263
# Epoch 116/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1031 - accuracy: 0.9925 - val_loss: 0.8692 - val_accuracy: 0.4737
# Epoch 117/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1135 - accuracy: 0.9925 - val_loss: 1.2414 - val_accuracy: 0.5263
# Epoch 118/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1138 - accuracy: 0.9925 - val_loss: 1.3684 - val_accuracy: 0.5789
# Epoch 119/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.
200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4155 - accuracy: 1.0000 - val_loss: 1.2219 - val_accuracy: 0.5263
# Epoch 151/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.4034 - accuracy: 1.0000 - val_loss: 0.7522 - val_accuracy: 0.5263
# Epoch 152/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3965 - accuracy: 1.0000 - val_loss: 0.6644 - val_accuracy: 0.6316
# Epoch 153/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3968 - accuracy: 0.9925 - val_loss: 0.7276 - val_accuracy: 0.5789
# Epoch 154/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3989 - accuracy: 1.0000 - val_loss: 0.7840 - val_accuracy: 0.5263
# Epoch 155/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4058 - accuracy: 1.0000 - val_loss: 0.7248 - val_accuracy: 0.5789
# Epoch 156/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3913 - accuracy: 1.0000 - val_loss: 0.6821 - val_accuracy: 0.5789
# Epoch 157/200
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3906 - accuracy: 1.0000 - val_loss: 0.6709 - val_accuracy: 0.6316
# Epoch 158/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3967 - accuracy: 1.0000 - val_loss: 0.6859 - val_accuracy: 0.5789
# Epoch 159/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3894 - accuracy: 1.0000 - val_loss: 0.6826 - val_accuracy: 0.5789
# Epoch 160/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3927 - accuracy: 1.0000 - val_loss: 0.6768 - val_accuracy: 0.5789
# Epoch 161/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3878 - accuracy: 1.0000 - val_loss: 0.6755 - val_accuracy: 0.5789
# Epoch 162/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.3871 - accuracy: 1.0000 - val_loss: 0.6762 - val_accuracy: 0.5789
# Epoch 163/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.3909 - accuracy: 1.0000 - val_loss: 0.6786 - val_accuracy: 0.5789
# Epoch 164/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3851 - accuracy: 1.0000 - val_loss: 0.6731 - val_accuracy: 0.5789
# Epoch 165/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.3877 - accuracy: 1.0000 - val_loss: 0.6769 - val_accuracy: 0.5789
# Epoch 166/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3862 - accuracy: 1.0000 - val_loss: 0.6707 - val_accuracy: 0.5789
# Epoch 167/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3978 - accuracy: 1.0000 - val_loss: 0.6684 - val_accuracy: 0.5789
# Epoch 168/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3873 - accuracy: 1.0000 - val_loss: 0.6823 - val_accuracy: 0.5789
# Epoch 169/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3896 - accuracy: 1.0000 - val_loss: 0.6709 - val_accuracy: 0.5789
# Epoch 170/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3853 - accuracy: 1.0000 - val_loss: 0.6648 - val_accuracy: 0.6316
# Epoch 171/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3818 - accuracy: 1.0000 - val_loss: 0.6747 - val_accuracy: 0.5789
# Epoch 172/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3811 - accuracy: 1.0000 - val_loss: 0.6820 - val_accuracy: 0.5789
# Epoch 173/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3826 - accuracy: 1.0000 - val_loss: 0.6679 - val_accuracy: 0.5789
# Epoch 174/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3805 - accuracy: 1.0000 - val_loss: 0.6704 - val_accuracy: 0.5789
# Epoch 175/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3821 - accuracy: 1.0000 - val_loss: 0.6722 - val_accuracy: 0.5789
# Epoch 176/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3840 - accuracy: 1.0000 - val_loss: 0.6694 - val_accuracy: 0.5789
# Epoch 177/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3811 - accuracy: 1.0000 - val_loss: 0.6738 - val_accuracy: 0.5789
# Epoch 178/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3881 - accuracy: 1.0000 - val_loss: 0.6678 - val_accuracy: 0.5789
# Epoch 179/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3800 - accuracy: 1.0000 - val_loss: 0.6710 - val_accuracy: 0.5789
# Epoch 180/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3855 - accuracy: 1.0000 - val_loss: 0.6675 - val_accuracy: 0.5789
# Epoch 181/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3792 - accuracy: 1.0000 - val_loss: 0.6667 - val_accuracy: 0.5789
# Epoch 182/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3822 - accuracy: 1.0000 - val_loss: 0.6696 - val_accuracy: 0.5789
# Epoch 183/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3793 - accuracy: 1.0000 - val_loss: 0.6682 - val_accuracy: 0.5789
# Epoch 184/200
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3805 - accuracy: 1.0000 - val_loss: 0.6680 - val_accuracy: 0.5789
# Epoch 185/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3821 - accuracy: 1.0000 - val_loss: 0.6690 - val_accuracy: 0.5789
# Epoch 186/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3865 - accuracy: 0.9851 - val_loss: 0.6654 - val_accuracy: 0.5789
# Epoch 187/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3759 - accuracy: 1.0000 - val_loss: 0.6649 - val_accuracy: 0.5789
# Epoch 188/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3771 - accuracy: 1.0000 - val_loss: 0.6715 - val_accuracy: 0.5789
# Epoch 189/200
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3740 - accuracy: 1.0000 - val_loss: 0.6640 - val_accuracy: 0.6316
# Epoch 190/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3725 - accuracy: 1.0000 - val_loss: 0.6657 - val_accuracy: 0.5789
# Epoch 191/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3714 - accuracy: 1.0000 - val_loss: 0.6677 - val_accuracy: 0.5789
# Epoch 192/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3830 - accuracy: 1.0000 - val_loss: 0.6634 - val_accuracy: 0.6316
# Epoch 193/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3766 - accuracy: 1.0000 - val_loss: 0.6676 - val_accuracy: 0.5789
# Epoch 194/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3727 - accuracy: 1.0000 - val_loss: 0.6635 - val_accuracy: 0.5789
# Epoch 195/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.3772 - accuracy: 1.0000 - val_loss: 0.6646 - val_accuracy: 0.5789
# Epoch 196/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3843 - accuracy: 1.0000 - val_loss: 0.6631 - val_accuracy: 0.5789
# Epoch 197/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3698 - accuracy: 1.0000 - val_loss: 0.6636 - val_accuracy: 0.5789
# Epoch 198/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3713 - accuracy: 1.0000 - val_loss: 0.6625 - val_accuracy: 0.5789
# Epoch 199/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.3746 - accuracy: 1.0000 - val_loss: 0.6642 - val_accuracy: 0.5789
# Epoch 200/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3715 - accuracy: 1.0000 - val_loss: 0.6616 - val_accuracy: 0.6316
# 2/2 - 0s - loss: 0.7354 - accuracy: 0.5641 - 43ms/epoch - 22ms/step
# Masked Transverse Test Accuracy: 0.5641025900840759

# %% [markdown]
# 수정ver
# 1. 모델층 추가
# 2. dropout 추가
# 3. lr 조정 (빠른 학습)

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.optimizers import Adam
import numpy as np
####################################
## 5. 데이터 준비
####################################
# Transverse와 Masked Transverse 데이터를 준비합니다.

# Transverse 데이터 평탄화
X_train_transverse = train_transverse_gfc.reshape(train_transverse_gfc.shape[0], -1)
X_val_transverse = val_transverse_gfc.reshape(val_transverse_gfc.shape[0], -1)
X_test_transverse = test_transverse_gfc.reshape(test_transverse_gfc.shape[0], -1)

# Masked Transverse 데이터 평탄화
X_train_masked = train_transverse_masked.reshape(train_transverse_masked.shape[0], -1)
X_val_masked = val_transverse_masked.reshape(val_transverse_masked.shape[0], -1)
X_test_masked = test_transverse_masked.reshape(test_transverse_masked.shape[0], -1)

# 레이블은 동일하므로 재사용
Y_train = np.eye(2)[train_labels]
Y_val = np.eye(2)[val_labels]
Y_test = np.eye(2)[test_labels]

####################################
## 6. 모델 정의 함수 (수정된 부분)
####################################
def create_model(input_dim):
    model = Sequential()
    model.add(Dense(64, input_dim=input_dim, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))  # Dropout 추가

    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))  # Dropout 추가

    model.add(Dense(2, activation='softmax'))  # 2개의 클래스

    # Adam 옵티마이저에서 learning_rate를 0.001로 변경
    adam = Adam(learning_rate=0.001)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model


####################################
## 7. Transverse 데이터 학습
####################################
model_transverse = create_model(X_train_transverse.shape[1])
history_transverse = model_transverse.fit(
    X_train_transverse, Y_train, validation_data=(X_val_transverse, Y_val),
    epochs=200, batch_size=43, verbose=1
)

# 테스트 평가
test_loss_transverse, test_acc_transverse = model_transverse.evaluate(X_test_transverse, Y_test, verbose=2)
print(f"Transverse Test Accuracy: {test_acc_transverse}")

####################################
## 8. Masked Transverse 데이터 학습
####################################
model_masked = create_model(X_train_masked.shape[1])
history_masked = model_masked.fit(
    X_train_masked, Y_train, validation_data=(X_val_masked, Y_val),
    epochs=200, batch_size=43, verbose=1
)

# 테스트 평가
test_loss_masked, test_acc_masked = model_masked.evaluate(X_test_masked, Y_test, verbose=2)
print(f"Masked Transverse Test Accuracy: {test_acc_masked}")

####################################
## 9. 정확도 및 로스 그래프 그리기
####################################
# 학습 정확도와 손실을 시각화
def plot_history(histories, title):
    plt.figure(figsize=(10, 5))

    # 정확도
    plt.subplot(1, 2, 1)
    for name, history in histories:
        plt.plot(history.history['accuracy'], label=f'{name} Train')
        plt.plot(history.history['val_accuracy'], label=f'{name} Val')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # 손실
    plt.subplot(1, 2, 2)
    for name, history in histories:
        plt.plot(history.history['loss'], label=f'{name} Train')
        plt.plot(history.history['val_loss'], label=f'{name} Val')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# 두 모델의 학습 결과를 시각화
plot_history(
    [('Transverse', history_transverse), ('Masked Transverse', history_masked)],
    'Comparison of Transverse and Masked Transverse'
)
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E53FB6AF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E53FB6AF78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/4 [=====================>........] - ETA: 0s - loss: 1.1262 - accuracy: 0.5426WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E5491B4708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E5491B4708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 4/4 [==============================] - 1s 190ms/step - loss: 1.1104 - accuracy: 0.5522 - val_loss: 1.7239 - val_accuracy: 0.4737
# Epoch 2/200
# 4/4 [==============================] - 0s 68ms/step - loss: 0.7208 - accuracy: 0.6493 - val_loss: 1.9041 - val_accuracy: 0.4737
# Epoch 3/200
# 4/4 [==============================] - 0s 38ms/step - loss: 0.7933 - accuracy: 0.7612 - val_loss: 1.5898 - val_accuracy: 0.4737
# Epoch 4/200
# 4/4 [==============================] - 0s 25ms/step - loss: 0.7442 - accuracy: 0.7090 - val_loss: 1.1987 - val_accuracy: 0.5789
# Epoch 5/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7176 - accuracy: 0.6791 - val_loss: 1.2139 - val_accuracy: 0.5789
# Epoch 6/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6750 - accuracy: 0.7015 - val_loss: 1.5596 - val_accuracy: 0.4211
# Epoch 7/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7933 - accuracy: 0.6866 - val_loss: 2.1558 - val_accuracy: 0.4211
# Epoch 8/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5207 - accuracy: 0.8060 - val_loss: 2.6494 - val_accuracy: 0.4211
# Epoch 9/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.7262 - accuracy: 0.7612 - val_loss: 3.4755 - val_accuracy: 0.4211
# Epoch 10/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7382 - accuracy: 0.7164 - val_loss: 3.8611 - val_accuracy: 0.4737
# Epoch 11/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6681 - accuracy: 0.7612 - val_loss: 4.0855 - val_accuracy: 0.4737
# Epoch 12/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6902 - accuracy: 0.7463 - val_loss: 4.0869 - val_accuracy: 0.4737
# Epoch 13/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5038 - accuracy: 0.7985 - val_loss: 3.9334 - val_accuracy: 0.4737
# Epoch 14/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6453 - accuracy: 0.7313 - val_loss: 3.3838 - val_accuracy: 0.4737
# Epoch 15/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5871 - accuracy: 0.7463 - val_loss: 2.5036 - val_accuracy: 0.4211
# Epoch 16/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5674 - accuracy: 0.7463 - val_loss: 1.3114 - val_accuracy: 0.5263
# Epoch 17/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6645 - accuracy: 0.7836 - val_loss: 1.0891 - val_accuracy: 0.5789
# Epoch 18/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.
200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1987 - accuracy: 0.9179 - val_loss: 1.5080 - val_accuracy: 0.5263
# Epoch 190/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2450 - accuracy: 0.9104 - val_loss: 1.2994 - val_accuracy: 0.5263
# Epoch 191/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2302 - accuracy: 0.8955 - val_loss: 0.9402 - val_accuracy: 0.6842
# Epoch 192/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4515 - accuracy: 0.8433 - val_loss: 0.8677 - val_accuracy: 0.7368
# Epoch 193/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2705 - accuracy: 0.8881 - val_loss: 0.8436 - val_accuracy: 0.7368
# Epoch 194/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4442 - accuracy: 0.7836 - val_loss: 0.8400 - val_accuracy: 0.7368
# Epoch 195/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2382 - accuracy: 0.9104 - val_loss: 0.8606 - val_accuracy: 0.7368
# Epoch 196/200
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2940 - accuracy: 0.8806 - val_loss: 0.9416 - val_accuracy: 0.7368
# Epoch 197/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2518 - accuracy: 0.8731 - val_loss: 1.1803 - val_accuracy: 0.5789
# Epoch 198/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2185 - accuracy: 0.9030 - val_loss: 1.4600 - val_accuracy: 0.5263
# Epoch 199/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2032 - accuracy: 0.9030 - val_loss: 1.7053 - val_accuracy: 0.5789
# Epoch 200/200
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1619 - accuracy: 0.9328 - val_loss: 2.0792 - val_accuracy: 0.5263
# 2/2 - 0s - loss: 2.6934 - accuracy: 0.4872 - 32ms/epoch - 16ms/step
# Masked Transverse Test Accuracy: 0.4871794879436493

# %% [markdown]
# # 모델 2
# https://www.kaggle.com/code/jeongwoopark/alzheimer-detection-and-classification-98-7-acc

# %% [markdown]
# 1. VGG16
#
# 배치를 아주 작게(3) 조정했는데도 여전히 GPU가 터짐

# %%
import cv2
from keras.applications.vgg16 import VGG16
from keras.models import Sequential
from keras.layers import Flatten, Dense
from sklearn.preprocessing import LabelEncoder

# Convert grayscale to 3-channel RGB for VGG16
def to_rgb(img):
    img_rgb = np.repeat(img, 3, axis=-1)
    return img_rgb

# Convert and stack images
def convert_to_rgb(image_array):
    rgb_list = [to_rgb(img) for img in image_array]
    return np.stack(rgb_list)

# Prepare the RGB datasets
train_transverse_gfc_rgb = convert_to_rgb(train_transverse_gfc)
val_transverse_gfc_rgb = convert_to_rgb(val_transverse_gfc)
test_transverse_gfc_rgb = convert_to_rgb(test_transverse_gfc)

train_transverse_masked_rgb = convert_to_rgb(train_transverse_masked)
val_transverse_masked_rgb = convert_to_rgb(val_transverse_masked)
test_transverse_masked_rgb = convert_to_rgb(test_transverse_masked)

# Label encoding
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(train_labels)
y_val_encoded = label_encoder.transform(val_labels)
y_test_encoded = label_encoder.transform(test_labels)

# Define VGG16 model
vgg16 = VGG16(weights='imagenet', input_shape=(224, 224, 3), include_top=False)
vgg16.trainable = False

# Transverse Images VGG16 Model
vgg16_model_transverse = Sequential()
vgg16_model_transverse.add(vgg16)
vgg16_model_transverse.add(Flatten(name='flatten'))
vgg16_model_transverse.add(Dense(2, activation='softmax', name='predictions'))
vgg16_model_transverse.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Transverse Masked Images VGG16 Model
vgg16_model_transverse_masked = Sequential()
vgg16_model_transverse_masked.add(vgg16)
vgg16_model_transverse_masked.add(Flatten(name='flatten'))
vgg16_model_transverse_masked.add(Dense(2, activation='softmax', name='predictions'))
vgg16_model_transverse_masked.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train VGG16 with Transverse Images
vgg16_model_transverse.fit(train_transverse_gfc_rgb, y_train_encoded, validation_data=(val_transverse_gfc_rgb, y_val_encoded), epochs=10, batch_size=3)

# Train VGG16 with Masked Transverse Images
vgg16_model_transverse_masked.fit(train_transverse_masked_rgb, y_train_encoded, validation_data=(val_transverse_masked_rgb, y_val_encoded), epochs=10, batch_size=7)

# Evaluate models
print("Evaluation for VGG16 on Transverse Images:")
vgg16_model_transverse.evaluate(test_transverse_gfc_rgb, y_test_encoded)

print("Evaluation for VGG16 on Masked Transverse Images:")
vgg16_model_transverse_masked.evaluate(test_transverse_masked_rgb, y_test_encoded)
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E4ABF81558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E4ABF81558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 45/45 [==============================] - ETA: 0s - loss: 1.5446 - accuracy: 0.5597WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E4ABF94948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E4ABF94948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 45/45 [==============================] - 5s 75ms/step - loss: 1.5446 - accuracy: 0.5597 - val_loss: 1.5037 - val_accuracy: 0.4737
# Epoch 2/10
# 45/45 [==============================] - 2s 45ms/step - loss: 0.9182 - accuracy: 0.6791 - val_loss: 0.8065 - val_accuracy: 0.6842
# Epoch 3/10
# 45/45 [==============================] - 2s 45ms/step - loss: 0.4266 - accuracy: 0.7761 - val_loss: 0.7049 - val_accuracy: 0.5789
# Epoch 4/10
# 45/45 [==============================] - 2s 45ms/step - loss: 0.6217 - accuracy: 0.7463 - val_loss: 0.8806 - val_accuracy: 0.6842
# Epoch 5/10
# 45/45 [==============================] - 2s 46ms/step - loss: 0.2594 - accuracy: 0.8955 - val_loss: 1.7510 - val_accuracy: 0.5263
# Epoch 6/10
# 45/45 [==============================] - 2s 46ms/step - loss: 0.2056 - accuracy: 0.9179 - val_loss: 0.6466 - val_accuracy: 0.6316
# Epoch 7/10
# 45/45 [==============================] - 2s 49ms/step - loss: 0.1077 - accuracy: 0.9851 - val_loss: 0.6962 - val_accuracy: 0.6316
# Epoch 8/10
# 45/45 [==============================] - 3s 57ms/step - loss: 0.1475 - accuracy: 0.9328 - val_loss: 0.7266 - val_accuracy: 0.6316
# Epoch 9/10
# 45/45 [==============================] - 3s 62ms/step - loss: 0.0673 - accuracy: 0.9925 - val_loss: 0.7037 - val_accuracy: 0.6316
# Epoch 10/10
# 45/45 [==============================] - 3s 64ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.6345 - val_accuracy: 0.6842
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E4ABF47C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E4ABF47C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 19/20 [===========================>..] - ETA: 0s - loss: 1.2509 - accuracy: 0.5639WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E520F35B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E520F35B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 20/20 [==============================] - 3s 127ms/step - loss: 1.2643 - accuracy: 0.5597 - val_loss: 1.1856 - val_accuracy: 0.4737
# Epoch 2/10
# 20/20 [==============================] - 2s 117ms/step - loss: 0.5697 - accuracy: 0.7537 - val_loss: 0.5634 - val_accuracy: 0.7368
# Epoch 3/10
# 20/20 [==============================] - 2s 117ms/step - loss: 0.5620 - accuracy: 0.7313 - val_loss: 0.5544 - val_accuracy: 0.6842
# Epoch 4/10
# 20/20 [==============================] - 2s 117ms/step - loss: 0.4110 - accuracy: 0.7761 - val_loss: 0.7353 - val_accuracy: 0.5789
# Epoch 5/10
# 20/20 [==============================] - 2s 117ms/step - loss: 0.5182 - accuracy: 0.7687 - val_loss: 1.1505 - val_accuracy: 0.5263
# Epoch 6/10
# 20/20 [==============================] - 2s 117ms/step - loss: 0.5295 - accuracy: 0.7313 - val_loss: 1.0303 - val_accuracy: 0.5263
# Epoch 7/10
# 20/20 [==============================] - 2s 117ms/step - loss: 0.3955 - accuracy: 0.8209 - val_loss: 0.5631 - val_accuracy: 0.7368
# Epoch 8/10
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1854 - accuracy: 0.9328 - val_loss: 0.7547 - val_accuracy: 0.6316
# Epoch 9/10
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1621 - accuracy: 0.9776 - val_loss: 0.5634 - val_accuracy: 0.7368
# Epoch 10/10
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1466 - accuracy: 0.9776 - val_loss: 0.5439 - val_accuracy: 0.7895
# Evaluation for VGG16 on Transverse Images:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14548\121529427.py in <module>
#      56 # Evaluate models
#      57 print("Evaluation for VGG16 on Transverse Images:")
# ---> 58 vgg16_model_transverse.evaluate(test_transverse_gfc_rgb, y_test_encoded)
#      59
#      60 print("Evaluation for VGG16 on Masked Transverse Images:")
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'sequential_14/vgg16/block1_conv2/Relu' defined at (most recent call last):
#     File "c:\Users\USER\.conda\envs\syrr\lib\runpy.py", line 193, in _run_module_as_main
#       "__main__", mod_spec)
#     File "c:\Users\USER\.conda\envs\syrr\lib\runpy.py", line 85, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#       app.start()
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\USER\.conda\envs\syrr\lib\asyncio\base_events.py", line 541, in run_forever
#       self._run_once()
#     File "c:\Users\USER\.conda\envs\syrr\lib\asyncio\base_events.py", line 1786, in _run_once
#       handle._run()
#     File "c:\Users\USER\.conda\envs\syrr\lib\asyncio\events.py", line 88, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\ipkernel.py", line 387, in do_execute
#       cell_id=cell_id,
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 2976, in run_cell
#       raw_cell, store_history, silent, shell_futures, cell_id
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 3030, in _run_cell
#       return runner(coro)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 3258, in run_cell_async
#       interactivity=interactivity, compiler=compiler, result=result)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 3473, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\USER\AppData\Local\Temp\ipykernel_14548\121529427.py", line 51, in <module>
#       vgg16_model_transverse.fit(train_transverse_gfc_rgb, y_train_encoded, validation_data=(val_transverse_gfc_rgb, y_val_encoded), epochs=10, batch_size=3)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1617, in fit
#       _use_cached_eval_dataset=True,
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1947, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1727, in test_function
#       return step_function(self, iterator)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1713, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1701, in run_step
#       outputs = model.test_step(data)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1665, in test_step
#       y_pred = self(x, training=False)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\layers\convolutional\base_conv.py", line 314, in call
#       return self.activation(outputs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\activations.py", line 318, in relu
#       x, alpha=alpha, max_value=max_value, threshold=threshold
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\backend.py", line 5366, in relu
#       x = tf.nn.relu(x)
# Node: 'sequential_14/vgg16/block1_conv2/Relu'
# OOM when allocating tensor with shape[32,64,224,224] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node sequential_14/vgg16/block1_conv2/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_test_function_78758]

# %% [markdown]
# 2. EfficientNetB0
#
# 마찬가지로 메모리가 터짐

# %%
import tensorflow as tf
import numpy as np

# Convert grayscale to 3-channel RGB for EfficientNetB0
def to_rgb(img):
    img_rgb = np.repeat(img, 3, axis=-1)  # 흑백 이미지를 3채널로 변환
    return img_rgb

# Convert and stack images
def convert_to_rgb(image_array):
    rgb_list = [to_rgb(img) for img in image_array]
    return np.stack(rgb_list)

# Prepare the RGB datasets (convert grayscale to RGB)
train_transverse_gfc_rgb = convert_to_rgb(train_transverse_gfc)
val_transverse_gfc_rgb = convert_to_rgb(val_transverse_gfc)
test_transverse_gfc_rgb = convert_to_rgb(test_transverse_gfc)

train_transverse_masked_rgb = convert_to_rgb(train_transverse_masked)
val_transverse_masked_rgb = convert_to_rgb(val_transverse_masked)
test_transverse_masked_rgb = convert_to_rgb(test_transverse_masked)

# Define EfficientNetB0 model for RGB images
def create_efficientnet_model(input_shape):
    EffNet = tf.keras.applications.EfficientNetB0(include_top=False, input_shape=input_shape)
    EffNet.trainable = True
    inputs = tf.keras.layers.Input(shape=input_shape, name='input_layer')
    x = EffNet(inputs)
    x = tf.keras.layers.GlobalAveragePooling2D(name='global_average_pooling_layer')(x)
    outputs = tf.keras.layers.Dense(2, activation='softmax', name='output_layer')(x)
    model = tf.keras.Model(inputs, outputs)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
    return model

# Set input shape for RGB images (3 channels)
input_shape = (224, 224, 3)

# Transverse EfficientNetB0 Model
efficientnet_model_transverse = create_efficientnet_model(input_shape)
efficientnet_model_transverse.fit(train_transverse_gfc_rgb, y_train_encoded, validation_data=(val_transverse_gfc_rgb, y_val_encoded), epochs=10, batch_size=32)

# Transverse Masked EfficientNetB0 Model
efficientnet_model_transverse_masked = create_efficientnet_model(input_shape)
efficientnet_model_transverse_masked.fit(train_transverse_masked_rgb, y_train_encoded, validation_data=(val_transverse_masked_rgb, y_val_encoded), epochs=10, batch_size=32)

# Evaluate models
print("Evaluation for EfficientNetB0 on Transverse Images:")
efficientnet_model_transverse.evaluate(test_transverse_gfc_rgb, y_test_encoded)

print("Evaluation for EfficientNetB0 on Masked Transverse Images:")
efficientnet_model_transverse_masked.evaluate(test_transverse_masked_rgb, y_test_encoded)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E417705C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001E417705C18> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14548\2707809093.py in <module>
#      38 # Transverse EfficientNetB0 Model
#      39 efficientnet_model_transverse = create_efficientnet_model(input_shape)
# ---> 40 efficientnet_model_transverse.fit(train_transverse_gfc_rgb, y_train_encoded, validation_data=(val_transverse_gfc_rgb, y_val_encoded), epochs=10, batch_size=32)
#      41
#      42 # Transverse Masked EfficientNetB0 Model
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'model/efficientnetb0/block2b_bn/FusedBatchNormV3' defined at (most recent call last):
#     File "c:\Users\USER\.conda\envs\syrr\lib\runpy.py", line 193, in _run_module_as_main
#       "__main__", mod_spec)
#     File "c:\Users\USER\.conda\envs\syrr\lib\runpy.py", line 85, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#       app.start()
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\USER\.conda\envs\syrr\lib\asyncio\base_events.py", line 541, in run_forever
#       self._run_once()
#     File "c:\Users\USER\.conda\envs\syrr\lib\asyncio\base_events.py", line 1786, in _run_once
#       handle._run()
#     File "c:\Users\USER\.conda\envs\syrr\lib\asyncio\events.py", line 88, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\ipkernel.py", line 387, in do_execute
#       cell_id=cell_id,
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 2976, in run_cell
#       raw_cell, store_history, silent, shell_futures, cell_id
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 3030, in _run_cell
#       return runner(coro)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 3258, in run_cell_async
#       interactivity=interactivity, compiler=compiler, result=result)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 3473, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\USER\AppData\Local\Temp\ipykernel_14548\2707809093.py", line 40, in <module>
#       efficientnet_model_transverse.fit(train_transverse_gfc_rgb, y_train_encoded, validation_data=(val_transverse_gfc_rgb, y_val_encoded), epochs=10, batch_size=32)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 850, in call
#       outputs = self._fused_batch_norm(inputs, training=training)
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 661, in _fused_batch_norm
#       training, _fused_batch_norm_training, _fused_batch_norm_inference
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\control_flow_util.py", line 109, in smart_cond
#       pred, true_fn=true_fn, false_fn=false_fn, name=name
#     File "c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 645, in _fused_batch_norm_training
#       exponential_avg_factor=exponential_avg_factor,
# Node: 'model/efficientnetb0/block2b_bn/FusedBatchNormV3'
# OOM when allocating tensor with shape[32,144,56,56] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model/efficientnetb0/block2b_bn/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_102761]

# %% [markdown]
# # 모델 3
# https://github.com/anilmenon14/OASIS_CNN_dementia_patterns

# %%
# 필요한 라이브러리 임포트
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import accuracy_score, log_loss
import matplotlib.pyplot as plt

# 입력 데이터 형태 정의 (이미 전처리된 데이터 사용)
transverse_input_shape = (224, 224, 1)  # Transverse 이미지 크기
masked_transverse_input_shape = (224, 224, 1)  # Masked Transverse 이미지 크기

# 모델 정의
def generate_model(input_shape):
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(2, activation='softmax'))  # 이진 분류: 치매(1), 비치매(0)
    
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# 모델 학습 및 평가 함수 정의
def generate_and_train_model(train_data, val_data, test_data, train_labels, val_labels, test_labels, input_shape):
    model = generate_model(input_shape)
    
    # 모델 학습
    history = model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=10, batch_size=32)
    
    # 모델 평가
    test_loss, test_accuracy = model.evaluate(test_data, test_labels)
    
    return model, history, test_loss, test_accuracy

# Transverse 이미지 모델 학습 및 평가
transverse_model, transverse_history, transverse_test_loss, transverse_test_accuracy = generate_and_train_model(
    train_transverse_gfc, val_transverse_gfc, test_transverse_gfc,
    train_labels, val_labels, test_labels, transverse_input_shape
)

# Masked Transverse 이미지 모델 학습 및 평가
masked_transverse_model, masked_transverse_history, masked_transverse_test_loss, masked_transverse_test_accuracy = generate_and_train_model(
    train_transverse_masked, val_transverse_masked, test_transverse_masked,
    train_labels, val_labels, test_labels, masked_transverse_input_shape
)

# 학습 결과 출력
print(f"Transverse 모델 테스트 정확도: {transverse_test_accuracy}")
print(f"Masked Transverse 모델 테스트 정확도: {masked_transverse_test_accuracy}")

# 정확도와 손실 그래프 그리기
def plot_accuracy_and_loss(history1, history2, title):
    plt.figure(figsize=(12, 5))

    # 정확도 그래프
    plt.subplot(1, 2, 1)
    plt.plot(history1.history['accuracy'], label='Transverse Accuracy')
    plt.plot(history1.history['val_accuracy'], label='Transverse Val Accuracy')
    plt.plot(history2.history['accuracy'], label='Masked Transverse Accuracy')
    plt.plot(history2.history['val_accuracy'], label='Masked Transverse Val Accuracy')
    plt.title(f'{title} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # 손실 그래프
    plt.subplot(1, 2, 2)
    plt.plot(history1.history['loss'], label='Transverse Loss')
    plt.plot(history1.history['val_loss'], label='Transverse Val Loss')
    plt.plot(history2.history['loss'], label='Masked Transverse Loss')
    plt.plot(history2.history['val_loss'], label='Masked Transverse Val Loss')
    plt.title(f'{title} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# 정확도와 손실 그래프 출력
plot_accuracy_and_loss(transverse_history, masked_transverse_history, 'Transverse vs Masked Transverse')
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14548\3177747832.py in <module>
#      41 transverse_model, transverse_history, transverse_test_loss, transverse_test_accuracy = generate_and_train_model(
#      42     train_transverse_gfc, val_transverse_gfc, test_transverse_gfc,
# ---> 43     train_labels, val_labels, test_labels, transverse_input_shape
#      44 )
#      45
#
# ~\AppData\Local\Temp\ipykernel_14548\3177747832.py in generate_and_train_model(train_data, val_data, test_data, train_labels, val_labels, test_labels, input_shape)
#      28 # 모델 학습 및 평가 함수 정의
#      29 def generate_and_train_model(train_data, val_data, test_data, train_labels, val_labels, test_labels, input_shape):
# ---> 30     model = generate_model(input_shape)
#      31
#      32     # 모델 학습
#
# ~\AppData\Local\Temp\ipykernel_14548\3177747832.py in generate_model(input_shape)
#      18     model.add(layers.Conv2D(128, (3, 3), activation='relu'))
#      19     model.add(layers.Flatten())
# ---> 20     model.add(layers.Dense(64, activation='relu'))
#      21     model.add(layers.Dense(2, activation='softmax'))  # 이진 분류: 치매(1), 비치매(0)
#      22
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\tensorflow\python\trackable\base.py in _method_wrapper(self, *args, **kwargs)
#     203     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204     try:
# --> 205       result = method(self, *args, **kwargs)
#     206     finally:
#     207       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\backend.py in random_uniform(self, shape, minval, maxval, dtype, nonce)
#    2103                 maxval=maxval,
#    2104                 dtype=dtype,
# -> 2105                 seed=seed,
#    2106             )
#    2107         return tf.random.uniform(
#
# ResourceExhaustedError: {{function_node __wrapped__StatelessRandomUniformV2_device_/job:localhost/replica:0/task:0/device:GPU:0}} OOM when allocating tensor with shape[346112,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:StatelessRandomUniformV2]

# %% [markdown]
# # 모델 4
# https://github.com/GMattheisen/predicting_Alzheimers_from_MRI

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

####################################
## 5. Model Definition and Training
####################################

# Define the CNN model from the repository
def build_alzheimer_model(input_shape):
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))  # Adjusted for binary classification (Dementia vs Non-dementia)

    model.compile(optimizer='adam', 
                  loss='binary_crossentropy', 
                  metrics=['accuracy'])
    return model

# Set input shape
input_shape = (224, 224, 1)

# Build models for both transverse and masked transverse data
transverse_model = build_alzheimer_model(input_shape)
masked_transverse_model = build_alzheimer_model(input_shape)

# Train and validate the models
history_transverse = transverse_model.fit(
    train_transverse_gfc, 
    train_labels, 
    epochs=10, 
    validation_data=(val_transverse_gfc, val_labels),
    batch_size=32
)

history_masked_transverse = masked_transverse_model.fit(
    train_transverse_masked, 
    train_labels, 
    epochs=10, 
    validation_data=(val_transverse_masked, val_labels),
    batch_size=32
)

# Evaluate the models
print("Transverse Model Evaluation:")
transverse_eval = transverse_model.evaluate(test_transverse_gfc, test_labels)
print("Masked Transverse Model Evaluation:")
masked_transverse_eval = masked_transverse_model.evaluate(test_transverse_masked, test_labels)

# Plot the accuracy and loss for both models
plt.figure(figsize=(12, 6))

# Transverse Model Accuracy and Loss
plt.subplot(1, 2, 1)
plt.plot(history_transverse.history['accuracy'], label='Train Accuracy (Transverse)')
plt.plot(history_transverse.history['val_accuracy'], label='Validation Accuracy (Transverse)')
plt.plot(history_masked_transverse.history['accuracy'], label='Train Accuracy (Masked Transverse)')
plt.plot(history_masked_transverse.history['val_accuracy'], label='Validation Accuracy (Masked Transverse)')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Transverse Model Loss
plt.subplot(1, 2, 2)
plt.plot(history_transverse.history['loss'], label='Train Loss (Transverse)')
plt.plot(history_transverse.history['val_loss'], label='Validation Loss (Transverse)')
plt.plot(history_masked_transverse.history['loss'], label='Train Loss (Masked Transverse)')
plt.plot(history_masked_transverse.history['val_loss'], label='Validation Loss (Masked Transverse)')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14548\412492794.py in <module>
#      33
#      34 # Build models for both transverse and masked transverse data
# ---> 35 transverse_model = build_alzheimer_model(input_shape)
#      36 masked_transverse_model = build_alzheimer_model(input_shape)
#      37
#
# ~\AppData\Local\Temp\ipykernel_14548\412492794.py in build_alzheimer_model(input_shape)
#      21     model.add(layers.MaxPooling2D((2, 2)))
#      22     model.add(layers.Flatten())
# ---> 23     model.add(layers.Dense(512, activation='relu'))
#      24     model.add(layers.Dense(1, activation='sigmoid'))  # Adjusted for binary classification (Dementia vs Non-dementia)
#      25
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\tensorflow\python\trackable\base.py in _method_wrapper(self, *args, **kwargs)
#     203     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204     try:
# --> 205       result = method(self, *args, **kwargs)
#     206     finally:
#     207       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\Users\USER\.conda\envs\syrr\lib\site-packages\keras\backend.py in random_uniform(self, shape, minval, maxval, dtype, nonce)
#    2103                 maxval=maxval,
#    2104                 dtype=dtype,
# -> 2105                 seed=seed,
#    2106             )
#    2107         return tf.random.uniform(
#
# ResourceExhaustedError: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:GPU:0}} failed to allocate memory [Op:Mul]
